# %%
import pandas as pd
import re
import json
import time
import requests
from requests.auth import HTTPBasicAuth
from elasticsearch import Elasticsearch
import elasticsearch
from elasticsearch.helpers import bulk

print(elasticsearch.__version__)
# Out:
# (8, 6, 2)

# %%
# !!! CUSTOMIZE THIS SECTION WITH YOUR CREDENTIALS !!!

USER = 'elastic'
PWD = '880A2904-264F-47F4-807B-DC9DDB47183B'
index_name = 'books'
ES_ENDPOINT = 'https://localhost:9200'

path_to_ca_certificates = './certs/ca/ca.crt'

# %% [markdown]
# ### Read data

# %%
df = pd.read_csv('books.csv')
df = df.set_index('id')
df.head()
# Out:
#                                                 author_name  \
# id
# 14602826                                      Yearsley, Ann
# 14602830                                              A, T.
# 14602831                                              A, T.
# 14602832  Albert, Prince Consort, consort of Victoria, Q...
# 14602833                                     Anslow, Robert
#
#                                                       title  country language  \
# id
# 14602826                         Poems on several occasions  England  English
# 14602830  A Satyr against Vertue. (A poem: supposed to b...  England  English
# 14602831  The Aeronaut, a poem; founded almost entirely,...  Ireland  English
# 14602832                          The Prince Albert, a poem  Ireland  English
# 14602833  The Defeat of the Spanish Armada, A.D. 1588. A...  England  English
#
#           year
# id
# 14602826  1786
# 14602830  1679
# 14602831  1816
# 14602832  1868
# 14602833  1888

# %%
#transform dataframe into json format
docs = df.to_dict(orient='records')
doc_ids = df.index
print(doc_ids[0])
print(docs[0])
# Out:
# 14602826
# {'author_name': 'Yearsley, Ann', 'title': 'Poems on several occasions', 'country': 'England', 'language': 'English', 'year': 1786}

# %% [markdown]
# ### Elasticsearch Python wrapper

# %%
def create_index(es, index_name, settings=None):
    """
    Create an Elasticsearch index
    @param es: an Elasticsearch object
    @param index_name: the name of the new index to be created
    @param settings: the index settings
    @return whether the index was created
    """
    is_created = False
    try:
        if es.indices.exists(index=[index_name]):
            es.indices.delete(index=[index_name], ignore=[404])
        es.indices.create(index=index_name, settings=settings)
        is_created = True
    except Exception as ex:
        print(str(ex))
    return is_created

# %%
# Index settings
settings_basic = {
        "number_of_shards": 4,
        "number_of_replicas": 2,
        "analysis": {
            "analyzer": {"std_english": {"type": "standard", "stopwords": "_english_" }}
        }
}

# %%
#connect to the local elasticsearch node and authenticate
es = Elasticsearch(hosts=[ES_ENDPOINT], ca_certs=path_to_ca_certificates, basic_auth=(USER, PWD))
#create an index
# is_created = create_index(es, index_name, settings=settings_basic)
# print(f'Index creation: {is_created}')
# Out:
# Index creation: True

# %%
#loops over the first 10 documents
for i, doc in zip(doc_ids[0:10], docs[0:10]):
    #index the documents with corresponding ids
    res = es.index(index=index_name, id=i, document=doc)
    print(res)
# see also the bulk functions for importing under: elasticsearch.helpers
# Out:
# {'_index': 'books', '_id': '14602826', '_version': 1, 'result': 'created', '_shards': {'total': 3, 'successful': 1, 'failed': 0}, '_seq_no': 0, '_primary_term': 1}
# {'_index': 'books', '_id': '14602830', '_version': 1, 'result': 'created', '_shards': {'total': 3, 'successful': 1, 'failed': 0}, '_seq_no': 0, '_primary_term': 1}
# {'_index': 'books', '_id': '14602831', '_version': 1, 'result': 'created', '_shards': {'total': 3, 'successful': 1, 'failed': 0}, '_seq_no': 0, '_primary_term': 1}
# {'_index': 'books', '_id': '14602832', '_version': 1, 'result': 'created', '_shards': {'total': 3, 'successful': 1, 'failed': 0}, '_seq_no': 1, '_primary_term': 1}
# {'_index': 'books', '_id': '14602833', '_version': 1, 'result': 'created', '_shards': {'total': 3, 'successful': 1, 'failed': 0}, '_seq_no': 1, '_primary_term': 1}
# {'_index': 'books', '_id': '14602834', '_version': 1, 'result': 'created', '_shards': {'total': 3, 'successful': 1, 'failed': 0}, '_seq_no': 0, '_primary_term': 1}
# {'_index': 'books', '_id': '14602835', '_version': 1, 'result': 'created', '_shards': {'total': 3, 'successful': 1, 'failed': 0}, '_seq_no': 2, '_primary_term': 1}
# {'_index': 'books', '_id': '14602836', '_version': 1, 'result': 'created', '_shards': {'total': 3, 'successful': 1, 'failed': 0}, '_seq_no': 1, '_primary_term': 1}
# {'_index': 'books', '_id': '14602837', '_version': 1, 'result': 'created', '_shards': {'total': 3, 'successful': 1, 'failed': 0}, '_seq_no': 1, '_primary_term': 1}
# {'_index': 'books', '_id': '14602838', '_version': 1, 'result': 'created', '_shards': {'total': 3, 'successful': 1, 'failed': 0}, '_seq_no': 2, '_primary_term': 1}

# %%
actions = [
  {
    "_index": index_name,
    "_id": doc_id,
    "_source": doc
  }
  for doc_id, doc in list(zip(doc_ids, docs))
]

# send actions in bulk (the API takes care of chunking them optimally)
bulk(es, actions)
# Out:
# (52695, [])

# %%
# get settings info of the selected index
es.indices.get_settings(index=index_name)
# Out:
# ObjectApiResponse({'books': {'settings': {'index': {'routing': {'allocation': {'include': {'_tier_preference': 'data_content'}}}, 'number_of_shards': '4', 'provided_name': 'books', 'creation_date': '1676638651484', 'analysis': {'analyzer': {'std_english': {'type': 'standard', 'stopwords': '_english_'}}}, 'number_of_replicas': '2', 'uuid': 'VCQkym_sTF2vgylZ9loxtw', 'version': {'created': '8050399'}}}}})

# %%
# retrieve a document with a given ID
es.get(index=index_name, id=doc_ids[1])
# Out:
# ObjectApiResponse({'_index': 'books', '_id': '14602830', '_version': 2, '_seq_no': 3, '_primary_term': 1, 'found': True, '_source': {'author_name': 'A, T.', 'title': 'A Satyr against Vertue. (A poem: supposed to be spoken by a Town-Hector )', 'country': 'England', 'language': 'English', 'year': 1679}})

# %%
# this is how you would delete the index
# es.indices.delete(index=index_name, ignore=404)

# %% [markdown]
# ### Elasticsearch with python cURL (Requests)

# %%
class Elastic:
    """
    A convenience object to send HTTP requests to Elasticsearch
    """
    def __init__(self, endpoint, username, password, path_to_ca_certificates):
        """
        @param endpoint: the URL of the Elasticsearch instance
        @param username: the Elasticsearch username 
        @param password: the Elasticsearch password
        """
        self.header = {'Content-Type': 'application/json', 'charset':'UTF-8'}
        #self.header={'Content-Type': '--data-binary application/x-ndjson'}
        self.endpoint = endpoint
        self.username = username
        self.password = password
        self.path_to_ca_certificates = path_to_ca_certificates
        self.methods_mapping = {'get': requests.get, 
                                'put':requests.put, 
                                'post':requests.post, 
                                'delete':requests.delete}
        
    def curl(self, method, handle, json=None):
        """
        Sends an HTTP request to the Elasticsearch instance
        @param method: can be 'get', 'put', 'post', 'delete'
        @param handle: the API handle to be appended to the Elasticsearch url
        @param json: the json payload of the HTTP request
        """
        http_method = self.methods_mapping[method.lower()]
        r = http_method(f'{self.endpoint}/{handle}', auth=HTTPBasicAuth(USER, PWD), 
                        headers=self.header, json=json,
                        verify = self.path_to_ca_certificates)
        return r

# %%
e = Elastic(ES_ENDPOINT, USER, PWD, path_to_ca_certificates)

# %%
# # create another index jsut as an example. in the following, we will keep using the book index
# # created using the Elasticsearch API

# create_index_json={
#   "mappings" : {
#       "properties" : {
#         "author_name" : {
#           "type" : "text"
#         },
#         "country" : {
#           "type" : "keyword"
#         },
#         "language" : {
#           "type" : "keyword"
#         },
#         "title" : {
#           "type" : "text"
#         },
#         "year" : {
#           "type" : "long"
#         }
#       }
#   },
#   "settings": {
#     "number_of_shards": 4, 
#     "number_of_replicas": 2, 
#     "index.max_result_window": 20000,
#     "index" : {
#         "similarity" : {
#           "default" : {
#             "type" : "BM25", "b": 0.75, "k1": 1.2
#           }
#         }
#     },
#     "analysis": {
#       "analyzer": {
#         "std_english": {"type": "standard", "stopwords": "_english_" }
#       }
#     }
#   }
# }

# # create an index
# r = e.curl('put', index_name, json=create_index_json)
# r.json()
# Out:
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'books'}

# %%
# # get the index details and settings
# r = e.curl('get', index_name)
# r.json()
# Out:
# {'books': {'aliases': {},
#   'mappings': {'properties': {'author_name': {'type': 'text'},
#     'country': {'type': 'keyword'},
#     'language': {'type': 'keyword'},
#     'title': {'type': 'text'},
#     'year': {'type': 'long'}}},
#   'settings': {'index': {'routing': {'allocation': {'include': {'_tier_preference': 'data_content'}}},
#     'number_of_shards': '4',
#     'provided_name': 'books',
#     'similarity': {'default': {'type': 'BM25', 'b': '0.75', 'k1': '1.2'}},
#     'max_result_window': '20000',
#     'creation_date': '1676639168957',
#     'analysis': {'analyzer': {'std_english': {'type': 'standard',
#        'stopwords': '_english_'}}},
#     'number_of_replicas': '2',
#     'uuid': 'pu8U4EsdTC6wZPOEDfRw9Q',
#     'version': {'created': '8050399'}}}}}

# %%
# # deactivate refresh in preparation of data indexing
# r = e.curl('put', 'books/_settings', {'index' : {'refresh_interval' : -1}})
# r.json()
# Out:
# {'acknowledged': True}

# %%
# # index documents with their individual ids (use bulk below for speedup)
# for doc_id, doc in list(zip(doc_ids, docs))[0:10]:
#     r = e.curl('post', f'books/_doc/{doc_id}', json=doc)
# r.json()
# Out:
# {'_index': 'books',
#  '_id': '14602838',
#  '_version': 3,
#  'result': 'updated',
#  '_shards': {'total': 3, 'successful': 1, 'failed': 0},
#  '_seq_no': 13082,
#  '_primary_term': 1}

# %%
# # bulk indexing (via official API)

# #connect to the local elasticsearch node and authenticate
# es = Elasticsearch([ES_ENDPOINT], ca_certs=path_to_ca_certificates, basic_auth=(USER, PWD))

# actions = [
#   {
#     "_index": index_name,
#     "_id": doc_id,
#     "_source": doc
#   }
#   for doc_id, doc in list(zip(doc_ids, docs))
# ]

# # send actions in bulk (the API takes care of chunking them optimally)
# bulk(es, actions)
# Out:
# (52695, [])

# %%
# # reset the refresh interval to 2 seconds
# r = e.curl('put', 'books/_settings', {'index' : {'refresh_interval' : '2s'}})
# r.json()
# Out:
# {'acknowledged': True}

# %%
# r = e.curl('get', f'books/_doc/{doc_ids[42]}')
# r.json()
# Out:
# {'_index': 'books',
#  '_id': '14602871',
#  '_version': 2,
#  '_seq_no': 13092,
#  '_primary_term': 1,
#  'found': True,
#  '_source': {'author_name': 'Smedley, Edward, Fellow of Sidney Sussex College, Cambridge',
#   'title': 'The Death of Saul and Jonathan. A poem',
#   'country': 'England',
#   'language': 'English',
#   'year': 1814}}

# %%
# this is how you would delete the index
r = e.curl('delete', 'books')
r.json()
# Out:
# {'acknowledged': True}

# %% [markdown]
# ### Search queries [EXERCISES]

# %% [markdown]
# #### Empty query

# %%
# empty query
# r = e.curl('get', f'books/_search')
# r.json()
# Out:
# {'error': {'root_cause': [{'type': 'index_not_found_exception',
#     'reason': 'no such index [books]',
#     'resource.type': 'index_or_alias',
#     'resource.id': 'books',
#     'index_uuid': '_na_',
#     'index': 'books'}],
#   'type': 'index_not_found_exception',
#   'reason': 'no such index [books]',
#   'resource.type': 'index_or_alias',
#   'resource.id': 'books',
#   'index_uuid': '_na_',
#   'index': 'books'},
#  'status': 404}

# %% [markdown]
# #### Aggregation query

# %%
# SETUP
# create another index jsut as an example. in the following, we will keep using the book index
# created using the Elasticsearch API

create_index_json={
  "mappings" : {
      "properties" : {
        "author_name" : {
          "type" : "text"
        },
        "country" : {
          "type" : "keyword"
        },
        "language" : {
          "type" : "keyword"
        },
        "title" : {
          "type" : "text"
        },
        "year" : {
          "type" : "long"
        }
      }
  },
  "settings": {
    "number_of_shards": 4, 
    "number_of_replicas": 2, 
    "index.max_result_window": 20000,
    "index" : {
        "similarity" : {
          "default" : {
            "type" : "BM25", "b": 0.75, "k1": 1.2
          }
        }
    },
    "analysis": {
      "analyzer": {
        "std_english": {"type": "standard", "stopwords": "_english_" }
      }
    }
  }
}

# create an index
r = e.curl('put', index_name, json=create_index_json)
r.json()
# Out:
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'books'}

# %%
r = e.curl('put', 'books/_settings', {'index' : {'refresh_interval' : -1}})
r.json()
# Out:
# {'acknowledged': True}

# %%
# bulk indexing (via official API)

#connect to the local elasticsearch node and authenticate
es = Elasticsearch([ES_ENDPOINT], ca_certs=path_to_ca_certificates, basic_auth=(USER, PWD))

actions = [
  {
    "_index": index_name,
    "_id": doc_id,
    "_source": doc
  }
  for doc_id, doc in list(zip(doc_ids, docs))
]

# send actions in bulk (the API takes care of chunking them optimally)
bulk(es, actions)
# Out:
# (52695, [])

# %%
""" 
EXERCISE A: 
execute an aggregation query to count the number of books writte in each country
"""
aggr_data = {
    "aggregations": {
        "by_category": {
            "terms": {
                "field": "country",
                "size": 10
            }
        }
    }
}

r = e.curl('get', f'books/_search', aggr_data)
r.json()
# Out:
# {'took': 7,
#  'timed_out': False,
#  '_shards': {'total': 4, 'successful': 4, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'books',
#     '_id': '14602831',
#     '_score': 1.0,
#     '_source': {'author_name': 'A, T.',
#      'title': 'The Aeronaut, a poem; founded almost entirely, upon a statement, printed in the newspapers, of a voyage from Dublin, in October, 1812',
#      'country': 'Ireland',
#      'language': 'English',
#      'year': 1816}},
#    {'_index': 'books',
#     '_id': '14602832',
#     '_score': 1.0,
#     '_source': {'author_name': 'Albert, Prince Consort, consort of Victoria, Queen of Great Britain',
#      'title': 'The Prince Albert, a poem',
#      'country': 'Ireland',
#      'language': 'English',
#      'year': 1868}},
#    {'_index': 'books',
#     '_id': '14602838',
#     '_score': 1.0,
#     '_source': {'author_name': 'Brabant, Henry, Sir',
#      'title': 'The Eve of the Revolution; in Newcastle-upon-Tyne. (The Case of Sir Henry Brabant, knt, Mayor of Newcastle upon Tyne, most humbly offered to your Majesties Royal consideration.)',
#      'country': 'England',
#      'language': 'English',
#      'year': 1848}},
#    {'_index': 'books',
#     '_id': '14602840',
#     '_score': 1.0,
#     '_source': {'author_name': 'Brown, Campbell Rae',
#      'title': 'Providence Point and Quartremaynes Quarry. For recitation',
#      'country': 'England ; United States of America',
#      'language': 'English',
#      'year': 1889}},
#    {'_index': 'books',
#     '_id': '14602842',
#     '_score': 1.0,
#     '_source': {'author_name': 'Charles, I., King of England',
#      'title': 'Songs for Christmas and the New Year, by Lucy A. Bennett, Rev. Richard Wilton , etc',
#      'country': 'England',
#      'language': 'English',
#      'year': 1886}},
#    {'_index': 'books',
#     '_id': '14602843',
#     '_score': 1.0,
#     '_source': {'author_name': 'Uncle Tim',
#      'title': 'Tom Cladpoles Jurney to Lunnun ... told by himself and written in pure Sussex doggerel by his Uncle Tim. The fifth thousand',
#      'country': 'England',
#      'language': 'English',
#      'year': 1887}},
#    {'_index': 'books',
#     '_id': '14602846',
#     '_score': 1.0,
#     '_source': {'author_name': 'Curtis, Walter',
#      'title': 'Book of Word & Music of Humorous Songs, Burlesque Sketches, & Recitals',
#      'country': 'England',
#      'language': 'English',
#      'year': 1896}},
#    {'_index': 'books',
#     '_id': '14602849',
#     '_score': 1.0,
#     '_source': {'author_name': 'Dryden, John',
#      'title': 'Emigration; or, England and Paris, a poem',
#      'country': 'England',
#      'language': 'English',
#      'year': 1816}},
#    {'_index': 'books',
#     '_id': '14602860',
#     '_score': 1.0,
#     '_source': {'author_name': 'Incledon, Charles Benjamin',
#      'title': 'The Wandering Melodist: or, The Rose, the thistle, and the Shamrock: consisting of fifteen songs, sung by Mr. I, etc',
#      'country': 'England',
#      'language': 'English',
#      'year': 1805}},
#    {'_index': 'books',
#     '_id': '14602871',
#     '_score': 1.0,
#     '_source': {'author_name': 'Smedley, Edward, Fellow of Sidney Sussex College, Cambridge',
#      'title': 'The Death of Saul and Jonathan. A poem',
#      'country': 'England',
#      'language': 'English',
#      'year': 1814}}]},
#  'aggregations': {'by_category': {'doc_count_error_upper_bound': 108,
#    'sum_other_doc_count': 6888,
#    'buckets': [{'key': 'England', 'doc_count': 41249},
#     {'key': 'United States of America', 'doc_count': 4558}]}}}

# %% [markdown]
# #### Full-text query

# %%
""" 
EXERCISE B: 
execute a full-text query for the query "love magic"
"""

b_query = {
  "query": {
    "match": {
      "title": {
        "query": "love magic"
      }
    }
  }
}

r = e.curl('get', f'books/_search', b_query)
r.json()
# Out:
# {'took': 7,
#  'timed_out': False,
#  '_shards': {'total': 4, 'successful': 4, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 456, 'relation': 'eq'},
#   'max_score': 15.985547,
#   'hits': [{'_index': 'books',
#     '_id': '14812010',
#     '_score': 15.985547,
#     '_source': {'author_name': 'Grant, Forrest, Mrs',
#      'title': 'The Magic of Love. A novel',
#      'country': 'England',
#      'language': 'English',
#      'year': 1874}},
#    {'_index': 'books',
#     '_id': '14628808',
#     '_score': 14.215401,
#     '_source': {'author_name': 'Dorisi, Lisa',
#      'title': 'The Enchanter; or, Love and Magic. A Musical Drama',
#      'country': 'England',
#      'language': 'English',
#      'year': 1760}},
#    {'_index': 'books',
#     '_id': '14816800',
#     '_score': 12.649038,
#     '_source': {'author_name': 'Lansdowne, George Granville, Baron',
#      'title': 'Poems upon Several Occasions. (The British Enchanters; or, No magic like love.)',
#      'country': 'England',
#      'language': 'English',
#      'year': 1712}},
#    {'_index': 'books',
#     '_id': '16286960',
#     '_score': 11.96598,
#     '_source': {'author_name': 'Gregory, Octavia',
#      'title': 'The Magic Garden',
#      'country': 'Scotland',
#      'language': 'English',
#      'year': 1920}},
#    {'_index': 'books',
#     '_id': '14805567',
#     '_score': 11.426906,
#     '_source': {'author_name': 'Bodkin, Matthias MacDonnell',
#      'title': 'White Magic. A novel',
#      'country': 'England',
#      'language': 'English',
#      'year': 1897}},
#    {'_index': 'books',
#     '_id': '14805312',
#     '_score': 10.564326,
#     '_source': {'author_name': 'Birrell, Olive M.',
#      'title': 'Behind the Magic Mirror',
#      'country': 'England',
#      'language': 'English',
#      'year': 1896}},
#    {'_index': 'books',
#     '_id': '14805360',
#     '_score': 10.146872,
#     '_source': {'author_name': 'Black, William',
#      'title': 'The Magic Ink, and other tales',
#      'country': 'England',
#      'language': 'English',
#      'year': 1892}},
#    {'_index': 'books',
#     '_id': '14891160',
#     '_score': 9.682161,
#     '_source': {'author_name': 'Dolan, John Gilbert',
#      'title': 'Westminster Abbey. (For use with the magic lantern.)',
#      'country': 'England',
#      'language': 'English',
#      'year': 1894}},
#    {'_index': 'books',
#     '_id': '16286512',
#     '_score': 9.544642,
#     '_source': {'author_name': 'Davies, W. H. (William Henry)',
#      'title': 'The Hour of Magic, and other poems ... Decorated by Wiliam Nicholson',
#      'country': 'England',
#      'language': 'English',
#      'year': 1922}},
#    {'_index': 'books',
#     '_id': '14756330',
#     '_score': 8.62096,
#     '_source': {'author_name': 'Rome (Italy)',
#      'title': 'Rome. A lecture for use with the magic lantern',
#      'country': 'England',
#      'language': 'English',
#      'year': 1896}}]}}

# %% [markdown]
# #### Exact match query

# %%
""" 
EXERCISE C: 
execute an exact-match query for the query "magic love"
"""

c_query = {
  "query": {
    "match_phrase": {
      "title": {
        "query": "magic love"
      }
    }
  }
}

r = e.curl('get', f'books/_search', c_query)
r.json()
# Out:
# {'took': 1,
#  'timed_out': False,
#  '_shards': {'total': 4, 'successful': 4, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 0, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []}}

# %% [markdown]
# #### Multi-field full-text query with field boosting

# %%
""" 
EXERCISE D: 
Execute a query that searches both on tile and author
Weights the importance of matches on the author field twice as much as matches on the title
Sse "shakespeare" as query term
"""

d_query =  {
    "query": {
        "multi_match": {
            "query": "shakespeare",
            "fields": ["title", "author^2"],
        }
    }
}

r = e.curl('get', f'books/_search', d_query)
r.json()
# Out:
# {'took': 1,
#  'timed_out': False,
#  '_shards': {'total': 4, 'successful': 4, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 60, 'relation': 'eq'},
#   'max_score': 9.891209,
#   'hits': [{'_index': 'books',
#     '_id': '14805353',
#     '_score': 9.891209,
#     '_source': {'author_name': 'Black, William',
#      'title': 'Judith Shakespeare: a romance',
#      'country': 'England',
#      'language': 'English',
#      'year': 1884}},
#    {'_index': 'books',
#     '_id': '14608354',
#     '_score': 9.353176,
#     '_source': {'author_name': 'Pearce, William',
#      'title': 'The Haunts of Shakespeare; a poem',
#      'country': 'England',
#      'language': 'English',
#      'year': 1778}},
#    {'_index': 'books',
#     '_id': '14824767',
#     '_score': 9.040419,
#     '_source': {'author_name': 'Williams, Robert Folkestone',
#      'title': 'The youth of Shakespeare',
#      'country': 'United States of America',
#      'language': 'English',
#      'year': 1840}},
#    {'_index': 'books',
#     '_id': '14829324',
#     '_score': 9.040419,
#     '_source': {'author_name': 'Shakespeare, William',
#      'title': 'Shakespeare traduit de langlois',
#      'country': 'France',
#      'language': 'French',
#      'year': 1776}},
#    {'_index': 'books',
#     '_id': '14817598',
#     '_score': 8.379654,
#     '_source': {'author_name': 'Lumley, Henry',
#      'title': 'Shakespeare. A revelation  ... Second edition',
#      'country': 'England',
#      'language': 'English',
#      'year': 1899}},
#    {'_index': 'books',
#     '_id': '14829354',
#     '_score': 7.711171,
#     '_source': {'author_name': 'Shakespeare, William',
#      'title': 'The Beauties of Shakespeare ... By W. Dodd',
#      'country': 'England',
#      'language': 'English',
#      'year': 1880}},
#    {'_index': 'books',
#     '_id': '14617068',
#     '_score': 7.6591744,
#     '_source': {'author_name': 'Tyrwhitt, Thomas',
#      'title': 'Observations and Conjectures upon some passages of Shakespeare',
#      'country': 'England',
#      'language': 'English',
#      'year': 1766}},
#    {'_index': 'books',
#     '_id': '14829357',
#     '_score': 7.1414638,
#     '_source': {'author_name': 'Montagu, Mrs (Elizabeth)',
#      'title': 'An Essay on the writings and genius of Shakespeare',
#      'country': 'England',
#      'language': 'English',
#      'year': 1770}},
#    {'_index': 'books',
#     '_id': '14608376',
#     '_score': 6.8717465,
#     '_source': {'author_name': 'Ross, James, of Liverpool',
#      'title': 'Shakespeare: an epistle to Mr Garrick; with an ode to Genius',
#      'country': 'England',
#      'language': 'English',
#      'year': 1760}},
#    {'_index': 'books',
#     '_id': '14818274',
#     '_score': 6.8174706,
#     '_source': {'author_name': 'Malone, Edmond',
#      'title': 'An attempt to ascertain the order in which the plays attributed to Shakespeare were written',
#      'country': 'England',
#      'language': 'English',
#      'year': 1785}}]}}

# %% [markdown]
# #### Combining different queries

# %%
"""
EXERCISE E:
execute a *single* boolean query returning books that:
- have the "queen mary" in the title and were written in England
- should NOT have been published in the range of years [1850-1913]
"""

e_query = {
    "query": {
        "bool": {
            "must": [
                {"match": {
                    "title": {
                        "query": "queen mary"
                    }
                }},
                {"match": {
                    "country": {
                        "query": "England"
                    }
                }}
            ],
            "must_not": [
                {"range": {"year": {"gte": 1850, "lte": 1913 }}}
            ]
        }
    }
}


r = e.curl('get', f'books/_search', e_query)
r.json()
# Out:
# {'took': 2,
#  'timed_out': False,
#  '_shards': {'total': 4, 'successful': 4, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 104, 'relation': 'eq'},
#   'max_score': 14.338542,
#   'hits': [{'_index': 'books',
#     '_id': '14828855',
#     '_score': 14.338542,
#     '_source': {'author_name': 'Saint John, John, Honourable',
#      'title': 'Mary Queen of Scots, a tragedy',
#      'country': 'England',
#      'language': 'English',
#      'year': 1789}},
#    {'_index': 'books',
#     '_id': '14866478',
#     '_score': 14.199584,
#     '_source': {'author_name': 'Buckingham, Leicester Silk',
#      'title': 'Memoirs of Mary Stuart, Queen of Scotland',
#      'country': 'England',
#      'language': 'English',
#      'year': 1844}},
#    {'_index': 'books',
#     '_id': '14816241',
#     '_score': 11.958053,
#     '_source': {'author_name': 'Banks, John',
#      'title': 'The Albion Queens, or, The Death of Mary Queen of Scotland',
#      'country': 'England',
#      'language': 'English',
#      'year': 1704}},
#    {'_index': 'books',
#     '_id': '14602983',
#     '_score': 11.878033,
#     '_source': {'author_name': 'Rymer, Thomas, antiquary',
#      'title': 'A Poem on the arrival of Queen Mary, Feb. the 12th, 1689',
#      'country': 'England',
#      'language': 'English',
#      'year': 1689}},
#    {'_index': 'books',
#     '_id': '14831583',
#     '_score': 11.503384,
#     '_source': {'author_name': 'Wallace, Albany',
#      'title': 'The Death of Mary Queen of Scots, an historic drama in five acts',
#      'country': 'England',
#      'language': 'English',
#      'year': 1827}},
#    {'_index': 'books',
#     '_id': '14872280',
#     '_score': 10.655148,
#     '_source': {'author_name': 'Madden, Frederic',
#      'title': 'Privy Purse expenses of the Princess Mary, daughter of King Henry the Eighth, afterwards Queen Mary. With a memoir of the Princess, and notes',
#      'country': 'England',
#      'language': 'English',
#      'year': 1831}},
#    {'_index': 'books',
#     '_id': '14847662',
#     '_score': 10.570174,
#     '_source': {'author_name': 'Mary, Queen of Scots',
#      'title': 'The Royal Exile; or, Poetical epistles of Mary, Queen of Scots, during her captivity in England: with other original poems. By a Young Lady  . Also, by her father  . the life of Queen Mary, etc',
#      'country': 'England',
#      'language': 'English',
#      'year': 1822}},
#    {'_index': 'books',
#     '_id': '14872656',
#     '_score': 9.6120615,
#     '_source': {'author_name': 'Raumer, Friedrich Ludwig Georg von',
#      'title': 'Contributions to Modern History, from the British Museum and the State Paper Office. vol. I. Queen Elizabeth and Mary Queen of Scots. (vol. 2. Frederick II. and his times.)',
#      'country': 'England',
#      'language': 'English',
#      'year': 1837}},
#    {'_index': 'books',
#     '_id': '14912491',
#     '_score': 9.102833,
#     '_source': {'author_name': 'Macauley, Elizabeth Wright, miss',
#      'title': 'Mary Stuart',
#      'country': 'England',
#      'language': 'English',
#      'year': 1823}},
#    {'_index': 'books',
#     '_id': '14817780',
#     '_score': 9.069041,
#     '_source': {'author_name': 'Macauley, Elizabeth Wright, miss',
#      'title': 'Mary Stuart',
#      'country': 'England',
#      'language': 'English',
#      'year': 1823}}]}}

# %% [markdown]
# #### Fuzzy queries

# %%
"""
EXERCISE F:
execute a fuzzy query for the query "comander" with at most 50 expansions 
and considering transpositions
"""

query_f = {
    "query": {
        "fuzzy": {
            "title": {
                "value": "comander", #the query
                "fuzziness": "AUTO", #maximum edit distance allowed, AUTO
                "max_expansions": 50, #maximum number of term variations created
                "prefix_length": 0, #characters left unchanged at start of term
                "transpositions": True, #to include transpositions in edits
            }
        }
    }
}

r = e.curl('get', f'books/_search', query_f)
r.json()
# Out:
# {'took': 16,
#  'timed_out': False,
#  '_shards': {'total': 4, 'successful': 4, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 64, 'relation': 'eq'},
#   'max_score': 8.783188,
#   'hits': [{'_index': 'books',
#     '_id': '14643500',
#     '_score': 8.783188,
#     '_source': {'author_name': 'Nesbit, E. (Edith)',
#      'title': 'A Pomander of Verse',
#      'country': 'England',
#      'language': 'English',
#      'year': 1895}},
#    {'_index': 'books',
#     '_id': '14804160',
#     '_score': 7.441244,
#     '_source': {'author_name': 'Armstrong, F. Claudius',
#      'title': 'The Neapolitan Commander, a romance of sea & land',
#      'country': 'England',
#      'language': 'English',
#      'year': 1863}},
#    {'_index': 'books',
#     '_id': '14810095',
#     '_score': 6.4313183,
#     '_source': {'author_name': 'Great Britain, Hydrographic Department',
#      'title': 'Report on the Bore of the Tsien-Tang Kiang, by Commander Moore',
#      'country': 'England',
#      'language': 'English',
#      'year': 1888}},
#    {'_index': 'books',
#     '_id': '14847207',
#     '_score': 6.4313183,
#     '_source': {'author_name': 'Great Britain, Hydrographic Department',
#      'title': 'Supplement ... Directions for Malacca Strait. Compiled by Staff Commander John Cumins Richards',
#      'country': 'England',
#      'language': 'English',
#      'year': 1876}},
#    {'_index': 'books',
#     '_id': '14807789',
#     '_score': 6.247992,
#     '_source': {'author_name': 'Comfort, Elizabeth Maxwell',
#      'title': 'The Young Commander. A novel. By the author of The Two Midshipmen , etc',
#      'country': 'England',
#      'language': 'English',
#      'year': 1856}},
#    {'_index': 'books',
#     '_id': '14810082',
#     '_score': 5.9579277,
#     '_source': {'author_name': 'Great Britain, Hydrographic Department',
#      'title': 'Sailing Directions for the Lower Shannon and for Lough Derg. By Commander J. Wolfe',
#      'country': 'England',
#      'language': 'English',
#      'year': 1850}},
#    {'_index': 'books',
#     '_id': '14871362',
#     '_score': 5.9255414,
#     '_source': {'author_name': 'Cajander, Karl Alexander',
#      'title': 'Uudenkaupungin muinaisia. Koonnut K. A. Cajander, etc. I. 1616-1647',
#      'country': 'England',
#      'language': 'Finnish',
#      'year': 1889}},
#    {'_index': 'books',
#     '_id': '14622827',
#     '_score': 5.8975806,
#     '_source': {'author_name': 'Great Britain, Hydrographic Department',
#      'title': 'Sailing Directions for the Lower Shannon and for Lough Derg. By Commander J. Wolfe',
#      'country': 'England',
#      'language': 'English',
#      'year': 1843}},
#    {'_index': 'books',
#     '_id': '14815177',
#     '_score': 5.7721686,
#     '_source': {'author_name': 'Kingston, William Henry Giles',
#      'title': 'The Three Commanders or, Active service afloat in modern days',
#      'country': 'England',
#      'language': 'English',
#      'year': 1891}},
#    {'_index': 'books',
#     '_id': '14885276',
#     '_score': 5.5375986,
#     '_source': {'author_name': 'Great Britain, Hydrographic Department',
#      'title': 'The China Sea Directory, vol. IV. ... Third edition. (This edition compiled by Staff-Commander W. N. Goalen.)',
#      'country': 'England',
#      'language': 'English',
#      'year': 1894}}]}}

# %% [markdown]
# #### Get TF of terms in document

# %%
"""
EXERCISE G:
get the term frequencies (in the title) of document with id = 4200
consider only words with a minimum length of 4 and a minimum term frequency of 2
"""

query_g =  {
  "fields" : ["title"],
  "term_statistics" : True,
  "field_statistics" : True,
  "positions": True,
  "filter": {
    "min_word_length": 4,
    "min_term_freq" : 2
  }
}

r = e.curl('get', f'books/_termvectors/{doc_ids[4200]}', query_g)
r.json()
# Out:
# {'_index': 'books',
#  '_id': '14767985',
#  '_version': 1,
#  'found': True,
#  'took': 1,
#  'term_vectors': {'title': {'field_statistics': {'sum_doc_freq': 148337,
#     'doc_count': 13216,
#     'sum_ttf': 166497},
#    'terms': {'with': {'doc_freq': 1908,
#      'ttf': 2076,
#      'term_freq': 2,
#      'tokens': [{'position': 9, 'start_offset': 52, 'end_offset': 56},
#       {'position': 24, 'start_offset': 135, 'end_offset': 139}],
#      'score': 5.8698487}}}}}

# %% [markdown]
# ### Solutions

# %%
# SOLUTION TO EXERCISE A

# aggregation query
query = {
    "aggregations": {
        "by_category": {
            "terms": {
                "field": "country",
                "size":100
            }
        }
    }
}
r = e.curl('get', f'books/_search', query)
r.json()
# Out:
# {'error': {'root_cause': [{'type': 'illegal_argument_exception',
#     'reason': 'Fielddata is disabled on [country] in [books]. Text fields are not optimised for operations that require per-document field data like aggregations and sorting, so these operations are disabled by default. Please use a keyword field instead. Alternatively, set fielddata=true on [country] in order to load field data by uninverting the inverted index. Note that this can use significant memory.'}],
#   'type': 'search_phase_execution_exception',
#   'reason': 'all shards failed',
#   'phase': 'query',
#   'grouped': True,
#   'failed_shards': [{'shard': 0,
#     'index': 'books',
#     'node': 'oPASJZaRRR-rQcIBczjcmw',
#     'reason': {'type': 'illegal_argument_exception',
#      'reason': 'Fielddata is disabled on [country] in [books]. Text fields are not optimised for operations that require per-document field data like aggregations and sorting, so these operations are disabled by default. Please use a keyword field instead. Alternatively, set fielddata=true on [country] in order to load field data by uninverting the inverted index. Note that this can use significant memory.'}}],
#   'caused_by': {'type': 'illegal_argument_exception',
#    'reason': 'Fielddata is disabled on [country] in [books]. Text fields are not optimised for operations that require per-document field data like aggregations and sorting, so these operations are disabled by default. Please use a keyword field instead. Alternatively, set fielddata=true on [country] in order to load field data by uninverting the inverted index. Note that this can use significant memory.',
#    'caused_by': {'type': 'illegal_argument_exception',
#     'reason': 'Fielddata is disabled on [country] in [books]. Text fields are not optimised for operations that require per-document field data like aggregations and sorting, so these operations are disabled by default. Please use a keyword field instead. Alternatively, set fielddata=true on [country] in order to load field data by uninverting the inverted index. Note that this can use significant memory.'}}},
#  'status': 400}

# %%
# SOLUTION TO EXERCISE B

# full-text query
query = {
    "query": {
        "match": {
            "title": {
                "query": "love magic"
            }
        }
    }
}
r = e.curl('get', f'books/_search', query)
r.json()
# Out:
# {'took': 40,
#  'timed_out': False,
#  '_shards': {'total': 4, 'successful': 4, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 456, 'relation': 'eq'},
#   'max_score': 16.060637,
#   'hits': [{'_index': 'books',
#     '_id': '14812010',
#     '_score': 16.060637,
#     '_source': {'author_name': 'Grant, Forrest, Mrs',
#      'title': 'The Magic of Love. A novel',
#      'country': 'England',
#      'language': 'English',
#      'year': 1874}},
#    {'_index': 'books',
#     '_id': '14628808',
#     '_score': 14.282113,
#     '_source': {'author_name': 'Dorisi, Lisa',
#      'title': 'The Enchanter; or, Love and Magic. A Musical Drama',
#      'country': 'England',
#      'language': 'English',
#      'year': 1760}},
#    {'_index': 'books',
#     '_id': '14816800',
#     '_score': 12.691303,
#     '_source': {'author_name': 'Lansdowne, George Granville, Baron',
#      'title': 'Poems upon Several Occasions. (The British Enchanters; or, No magic like love.)',
#      'country': 'England',
#      'language': 'English',
#      'year': 1712}},
#    {'_index': 'books',
#     '_id': '16286960',
#     '_score': 12.0739,
#     '_source': {'author_name': 'Gregory, Octavia',
#      'title': 'The Magic Garden',
#      'country': 'Scotland',
#      'language': 'English',
#      'year': 1920}},
#    {'_index': 'books',
#     '_id': '14805567',
#     '_score': 11.52996,
#     '_source': {'author_name': 'Bodkin, Matthias MacDonnell',
#      'title': 'White Magic. A novel',
#      'country': 'England',
#      'language': 'English',
#      'year': 1897}},
#    {'_index': 'books',
#     '_id': '14805312',
#     '_score': 10.618781,
#     '_source': {'author_name': 'Birrell, Olive M.',
#      'title': 'Behind the Magic Mirror',
#      'country': 'England',
#      'language': 'English',
#      'year': 1896}},
#    {'_index': 'books',
#     '_id': '14805360',
#     '_score': 10.219515,
#     '_source': {'author_name': 'Black, William',
#      'title': 'The Magic Ink, and other tales',
#      'country': 'England',
#      'language': 'English',
#      'year': 1892}},
#    {'_index': 'books',
#     '_id': '14891160',
#     '_score': 9.769466,
#     '_source': {'author_name': 'Dolan, John Gilbert',
#      'title': 'Westminster Abbey. (For use with the magic lantern.)',
#      'country': 'England',
#      'language': 'English',
#      'year': 1894}},
#    {'_index': 'books',
#     '_id': '16286512',
#     '_score': 9.737055,
#     '_source': {'author_name': 'Davies, W. H. (William Henry)',
#      'title': 'The Hour of Magic, and other poems ... Decorated by Wiliam Nicholson',
#      'country': 'England',
#      'language': 'English',
#      'year': 1922}},
#    {'_index': 'books',
#     '_id': '14756330',
#     '_score': 8.665326,
#     '_source': {'author_name': 'Rome (Italy)',
#      'title': 'Rome. A lecture for use with the magic lantern',
#      'country': 'England',
#      'language': 'English',
#      'year': 1896}}]}}

# %%
# SOLUTION TO EXERCISE C

# exact match query
query = {
  "query": {
    "match_phrase": {
      "title": {
        "query": "magic love"
      }
    }
  }
}
r = e.curl('get', f'books/_search', query)
r.json()
# Out:
# {'took': 1,
#  'timed_out': False,
#  '_shards': {'total': 4, 'successful': 4, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 0, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []}}

# %%
# SOLUTION TO EXERCISE D

# Full text query, multiple fields with boosting
query = {
"query": {
    "multi_match": {
            "query": "shakespeare",
            "fields": ["title", "author_name^2"],
            "type": "phrase"
        }
    }
}
r = e.curl('get', f'books/_search', query)
r.json()
# Out:
# {'took': 21,
#  'timed_out': False,
#  '_shards': {'total': 4, 'successful': 4, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 95, 'relation': 'eq'},
#   'max_score': 16.75016,
#   'hits': [{'_index': 'books',
#     '_id': '14628923',
#     '_score': 16.75016,
#     '_source': {'author_name': 'Shakespeare, William',
#      'title': 'A Midsummer Nights Dream : With alterations and additions and several new songs  . As it is performed at the Theatre-Royal in Drury-Lane',
#      'country': 'England',
#      'language': 'English',
#      'year': 1763}},
#    {'_index': 'books',
#     '_id': '14824041',
#     '_score': 16.75016,
#     '_ignored': ['title.keyword'],
#     '_source': {'author_name': 'Shakespeare, William',
#      'title': 'The plays of William Shakspeare. In ten volumes. With the corrections and illustrations of various commentators; to which are added notes by S. Johnson and G. Steevens. (An attempt to ascertain the order in which the plays attributed to Shakespeare were written, by E. Malone.) The second edition, revised and augmented',
#      'country': 'England',
#      'language': 'English',
#      'year': 1778}},
#    {'_index': 'books',
#     '_id': '14824045',
#     '_score': 16.75016,
#     '_source': {'author_name': 'Shakespeare, William',
#      'title': 'The Dramatic Works of William Shakspeare; with notes ... selected from the most eminent commentators: to which is prefixed a life of the author, by the Rev. W. Harness, etc',
#      'country': 'England',
#      'language': 'English',
#      'year': 1825}},
#    {'_index': 'books',
#     '_id': '14829326',
#     '_score': 16.75016,
#     '_source': {'author_name': 'Shakespeare, William',
#      'title': 'The School-Shakspeare; or, plays and scenes from Shakspeare illustrated for the use of Schools, with glossarial notes, selected from the best annotators, by the Rev. J. R. Pitman, etc',
#      'country': 'England',
#      'language': 'English',
#      'year': 1822}},
#    {'_index': 'books',
#     '_id': '14829334',
#     '_score': 16.75016,
#     '_source': {'author_name': 'Shakespeare, William',
#      'title': 'Shakespeares Julius Caesar',
#      'country': 'England',
#      'language': 'English',
#      'year': 1893}},
#    {'_index': 'books',
#     '_id': '14829342',
#     '_score': 16.75016,
#     '_source': {'author_name': 'Shakespeare, William',
#      'title': 'Romeo and Juliet : a tragedy',
#      'country': 'England',
#      'language': 'English',
#      'year': 1750}},
#    {'_index': 'books',
#     '_id': '14829343',
#     '_score': 16.75016,
#     '_source': {'author_name': 'Shakespeare, William',
#      'title': 'Romeo and Juliet : A tragedy. ... With notes by Dr. O. Fiebig',
#      'country': 'Germany',
#      'language': 'English',
#      'year': 1859}},
#    {'_index': 'books',
#     '_id': '14829353',
#     '_score': 16.75016,
#     '_source': {'author_name': 'Shakespeare, William',
#      'title': 'Selections from Shakspeare. By B. Oakley',
#      'country': 'England',
#      'language': 'English',
#      'year': 1828}},
#    {'_index': 'books',
#     '_id': '14829355',
#     '_score': 16.75016,
#     '_source': {'author_name': 'Shakespeare, William',
#      'title': 'The Mind of Shakspeare, as exhibited in his works',
#      'country': 'England',
#      'language': 'English',
#      'year': 1880}},
#    {'_index': 'books',
#     '_id': '15743093',
#     '_score': 16.75016,
#     '_source': {'author_name': 'Shakespeare, William',
#      'title': 'Stockdales Edition of Shakspeare; including, in one volume, the whole of his Dramatic Works; with explanatory notes compiled from various commentators. Embellished with a striking likeness of the author',
#      'country': 'England',
#      'language': 'English',
#      'year': 1784}}]}}

# %%
# SOLUTION TO EXERCISE E

# One or more queries can be specified in each of the clauses
# All the clauses are optional
# MUST: A document must match all of the queries
# MUST_NOT: A document must not match any of the queries
# SHOULD: A document does not have to match the queries, but it is considered more relevant if it does
# FILTER: Filters with yes/no categories
query = {
  "size" : 100,
  "query": {
    "bool": {
      "must": [
        {
          "match": {
                "title": "queen mary"
          }
        },
        {
          "match": {
              "country": "England"
          }
        }
      ],
      "must_not": [
        {
          "range": {
            "year": {
                "gte": 1850,
                "lte": 1913
            }
          }
        }
      ]
    }
  }
}
r = e.curl('get', f'books/_search', query)
r.json()
# Out:
# {'took': 12,
#  'timed_out': False,
#  '_shards': {'total': 4, 'successful': 4, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 104, 'relation': 'eq'},
#   'max_score': 14.338542,
#   'hits': [{'_index': 'books',
#     '_id': '14828855',
#     '_score': 14.338542,
#     '_source': {'author_name': 'Saint John, John, Honourable',
#      'title': 'Mary Queen of Scots, a tragedy',
#      'country': 'England',
#      'language': 'English',
#      'year': 1789}},
#    {'_index': 'books',
#     '_id': '14866478',
#     '_score': 14.199584,
#     '_source': {'author_name': 'Buckingham, Leicester Silk',
#      'title': 'Memoirs of Mary Stuart, Queen of Scotland',
#      'country': 'England',
#      'language': 'English',
#      'year': 1844}},
#    {'_index': 'books',
#     '_id': '14816241',
#     '_score': 11.958053,
#     '_source': {'author_name': 'Banks, John',
#      'title': 'The Albion Queens, or, The Death of Mary Queen of Scotland',
#      'country': 'England',
#      'language': 'English',
#      'year': 1704}},
#    {'_index': 'books',
#     '_id': '14602983',
#     '_score': 11.878033,
#     '_source': {'author_name': 'Rymer, Thomas, antiquary',
#      'title': 'A Poem on the arrival of Queen Mary, Feb. the 12th, 1689',
#      'country': 'England',
#      'language': 'English',
#      'year': 1689}},
#    {'_index': 'books',
#     '_id': '14831583',
#     '_score': 11.503384,
#     '_source': {'author_name': 'Wallace, Albany',
#      'title': 'The Death of Mary Queen of Scots, an historic drama in five acts',
#      'country': 'England',
#      'language': 'English',
#      'year': 1827}},
#    {'_index': 'books',
#     '_id': '14872280',
#     '_score': 10.655148,
#     '_source': {'author_name': 'Madden, Frederic',
#      'title': 'Privy Purse expenses of the Princess Mary, daughter of King Henry the Eighth, afterwards Queen Mary. With a memoir of the Princess, and notes',
#      'country': 'England',
#      'language': 'English',
#      'year': 1831}},
#    {'_index': 'books',
#     '_id': '14847662',
#     '_score': 10.570174,
#     '_source': {'author_name': 'Mary, Queen of Scots',
#      'title': 'The Royal Exile; or, Poetical epistles of Mary, Queen of Scots, during her captivity in England: with other original poems. By a Young Lady  . Also, by her father  . the life of Queen Mary, etc',
#      'country': 'England',
#      'language': 'English',
#      'year': 1822}},
#    {'_index': 'books',
#     '_id': '14872656',
#     '_score': 9.6120615,
#     '_source': {'author_name': 'Raumer, Friedrich Ludwig Georg von',
#      'title': 'Contributions to Modern History, from the British Museum and the State Paper Office. vol. I. Queen Elizabeth and Mary Queen of Scots. (vol. 2. Frederick II. and his times.)',
#      'country': 'England',
#      'language': 'English',
#      'year': 1837}},
#    {'_index': 'books',
#     '_id': '14912491',
#     '_score': 9.102833,
#     '_source': {'author_name': 'Macauley, Elizabeth Wright, miss',
#      'title': 'Mary Stuart',
#      'country': 'England',
#      'language': 'English',
#      'year': 1823}},
#    {'_index': 'books',
#     '_id': '14817780',
#     '_score': 9.069041,
#     '_source': {'author_name': 'Macauley, Elizabeth Wright, miss',
#      'title': 'Mary Stuart',
#      'country': 'England',
#      'language': 'English',
#      'year': 1823}},
#    {'_index': 'books',
#     '_id': '14871374',
#     '_score': 8.965339,
#     '_source': {'author_name': 'Campbell, Hugh, ll.d',
#      'title': 'The Case of Mary Queen of Scots, and of Elizabeth Queen of England, legally, briefly, and historically stated: embracing the amorous life of the Virgin Queen, and identifying her with all the plans that led to Marys ruin and murder. With an account of last moments of Mary, her letter to Elizabeth, and Davisons apology about the death warrant, etc',
#      'country': 'England',
#      'language': 'English',
#      'year': 1825}},
#    {'_index': 'books',
#     '_id': '14817781',
#     '_score': 8.965332,
#     '_source': {'author_name': 'Macauley, Elizabeth Wright, miss',
#      'title': 'Mary Stuart',
#      'country': 'England',
#      'language': 'English',
#      'year': 1823}},
#    {'_index': 'books',
#     '_id': '16286857',
#     '_score': 8.728313,
#     '_source': {'author_name': 'George, V., King of Great Britain',
#      'title': 'Welcome! Lines commemorative of the visit of ... King George V. and Queen Mary to Guernsey ... by the author of A Saga of Guernsey',
#      'country': 'England',
#      'language': 'English',
#      'year': 1921}},
#    {'_index': 'books',
#     '_id': '14939727',
#     '_score': 7.8353524,
#     '_source': {'author_name': 'Mary, Queen of Scots',
#      'title': 'The Legend of Mary, Queen of Scots  and other ancient poems, now first published from MSS. of the sixteenth century. With an introduction, notes, and an appendix  . L.P',
#      'country': 'England',
#      'language': 'English',
#      'year': 1810}},
#    {'_index': 'books',
#     '_id': '14809396',
#     '_score': 7.6371574,
#     '_source': {'author_name': 'Downing, Harriet',
#      'title': 'Mary; or Female Friendship: a poem',
#      'country': 'England',
#      'language': 'English',
#      'year': 1816}},
#    {'_index': 'books',
#     '_id': '14608671',
#     '_score': 7.6040525,
#     '_source': {'author_name': 'Hughes, John, M.A., of Oriel College, Oxford',
#      'title': 'Jack and the Queen Killers',
#      'country': 'England',
#      'language': 'English',
#      'year': 1820}},
#    {'_index': 'books',
#     '_id': '14829433',
#     '_score': 7.5771375,
#     '_source': {'author_name': 'Shelley, Percy Bysshe',
#      'title': 'Queen Mab; a philosophical poem',
#      'country': 'England',
#      'language': 'English',
#      'year': 1823}},
#    {'_index': 'books',
#     '_id': '14830213',
#     '_score': 7.5771375,
#     '_source': {'author_name': 'Stickney, afterwards Ellis, Sarah',
#      'title': 'The Island Queen: a poem',
#      'country': 'England',
#      'language': 'English',
#      'year': 1846}},
#    {'_index': 'books',
#     '_id': '14808053',
#     '_score': 7.482995,
#     '_source': {'author_name': 'Courtenay, Edward, Earl of Devon',
#      'title': 'Courtnay Earl of Devonshire; or, the Troubles of the Princess Elizabeth. A Tragedy. Comprehending a great part of the Reign of Queen Mary, with the Death of Jane Gray',
#      'country': 'England',
#      'language': 'English',
#      'year': 1705}},
#    {'_index': 'books',
#     '_id': '14939412',
#     '_score': 7.3570075,
#     '_source': {'author_name': 'Charles, II, King of England',
#      'title': 'A Lament for Englands Queen',
#      'country': 'England',
#      'language': 'English',
#      'year': 1818}},
#    {'_index': 'books',
#     '_id': '16288421',
#     '_score': 7.31176,
#     '_source': {'author_name': 'Skeat, Bertha Marian',
#      'title': 'The Crucifixion of Mary, and other poems',
#      'country': 'England',
#      'language': 'English',
#      'year': 1924}},
#    {'_index': 'books',
#     '_id': '14608501',
#     '_score': 7.272216,
#     '_source': {'author_name': 'Sanderson, A., Mrs',
#      'title': 'A Poem ... inscribed ... to ... the Queen',
#      'country': 'England',
#      'language': 'English',
#      'year': 1820}},
#    {'_index': 'books',
#     '_id': '14818680',
#     '_score': 7.168965,
#     '_source': {'author_name': 'Marwick, James David, Sir',
#      'title': 'Poor Mary; or, the Love Engagement. A romance',
#      'country': 'England',
#      'language': 'English',
#      'year': 1847}},
#    {'_index': 'books',
#     '_id': '14912194',
#     '_score': 7.063265,
#     '_source': {'author_name': 'Barford, Richard',
#      'title': 'The Virgin Queen. A tragedy, etc',
#      'country': 'England',
#      'language': 'English',
#      'year': 1729}},
#    {'_index': 'books',
#     '_id': '16288556',
#     '_score': 6.9690695,
#     '_source': {'author_name': 'Stuart, Dorothy Margaret',
#      'title': 'Lyrics of Old London ... Illustrated by Mary Ellis',
#      'country': 'England',
#      'language': 'English',
#      'year': 1915}},
#    {'_index': 'books',
#     '_id': '14608702',
#     '_score': 6.7629905,
#     '_source': {'author_name': 'Poser, Satiricus, pseudonym',
#      'title': 'The Queen in the Moon ... Second edition',
#      'country': 'England',
#      'language': 'English',
#      'year': 1820}},
#    {'_index': 'books',
#     '_id': '14608672',
#     '_score': 6.732548,
#     '_source': {'author_name': 'Hughes, John, M.A., of Oriel College, Oxford',
#      'title': 'The Political Queen that Jack loves ... Seventh edition',
#      'country': 'England',
#      'language': 'English',
#      'year': 1820}},
#    {'_index': 'books',
#     '_id': '14809644',
#     '_score': 6.7219915,
#     '_source': {'author_name': 'Duvard, Primogene',
#      'title': 'Mary Tudor: an historical drama, in five acts , etc',
#      'country': 'England',
#      'language': 'English',
#      'year': 1844}},
#    {'_index': 'books',
#     '_id': '14828952',
#     '_score': 6.587565,
#     '_source': {'author_name': 'Saunders, John',
#      'title': 'Songs, Sonnets, and miscellaneous poems of John and Mary Saunders',
#      'country': 'England',
#      'language': 'English',
#      'year': 1838}},
#    {'_index': 'books',
#     '_id': '14774178',
#     '_score': 6.5576534,
#     '_source': {'author_name': 'Powell, Thomas, of New York',
#      'title': 'The Shepherds Well, a play  . (Mary, or, the first love )',
#      'country': 'England',
#      'language': 'English',
#      'year': 1844}},
#    {'_index': 'books',
#     '_id': '14643422',
#     '_score': 6.54702,
#     '_source': {'author_name': 'Hayley, William',
#      'title': 'Occasional Stanzas, written at the request of the Revolution Society and recited on their anniversary, November 4, 1788. To which is added, Queen Mary to King William, during his Campaign in Ireland, 1690: a poetical Epistle',
#      'country': 'England',
#      'language': 'English',
#      'year': 1788}},
#    {'_index': 'books',
#     '_id': '14813500',
#     '_score': 6.520715,
#     '_source': {'author_name': 'Hogg, James',
#      'title': 'Queen Hynde. A poem. (Notices respecting names, places, etc.)',
#      'country': 'England',
#      'language': 'English',
#      'year': 1825}},
#    {'_index': 'books',
#     '_id': '14605585',
#     '_score': 6.5133867,
#     '_source': {'author_name': 'Aubin, Penelope',
#      'title': 'The Extasy. A Pindarick ode to ... the Queen',
#      'country': 'England',
#      'language': 'English',
#      'year': 1708}},
#    {'_index': 'books',
#     '_id': '16286016',
#     '_score': 6.5133867,
#     '_source': {'author_name': 'Balean, Alice Masters',
#      'title': 'Queen Bess in Borrowed Plumes ... and other poems',
#      'country': 'England',
#      'language': 'English',
#      'year': 1933}},
#    {'_index': 'books',
#     '_id': '14605608',
#     '_score': 6.3116403,
#     '_source': {'author_name': 'N, T., gent',
#      'title': 'A Poem on the Queen  . By T. N. Gent',
#      'country': 'England',
#      'language': 'English',
#      'year': 1695}},
#    {'_index': 'books',
#     '_id': '14816222',
#     '_score': 6.3116403,
#     '_source': {'author_name': 'Arend, Johannes Pieter',
#      'title': 'The Queen of Argos; a tragedy: in five acts',
#      'country': 'England',
#      'language': 'English',
#      'year': 1823}},
#    {'_index': 'books',
#     '_id': '16287348',
#     '_score': 6.3116403,
#     '_source': {'author_name': 'Lee, Sophia',
#      'title': 'Almeyda, Queen of Granada. A tragedy in five acts',
#      'country': 'England',
#      'language': 'English',
#      'year': 1796}},
#    {'_index': 'books',
#     '_id': '16288349',
#     '_score': 6.3116403,
#     '_source': {'author_name': 'Shanks, Edward',
#      'title': 'The Queen of China, and other poems. Second impression',
#      'country': 'England',
#      'language': 'English',
#      'year': 1919}},
#    {'_index': 'books',
#     '_id': '14826939',
#     '_score': 6.282208,
#     '_source': {'author_name': 'Hockley, W. B. (William Browne)',
#      'title': 'Panthea, Queen of Susia; a tragedy in five acts',
#      'country': 'England',
#      'language': 'English',
#      'year': 1809}},
#    {'_index': 'books',
#     '_id': '14840058',
#     '_score': 6.2469378,
#     '_source': {'author_name': 'Fuller, afterwards Ossoli, Sarah Margaret, marchioness',
#      'title': 'Hand Book to the Abbey of St. Mary of Furness, in Lancashire',
#      'country': 'England',
#      'language': 'English',
#      'year': 1845}},
#    {'_index': 'books',
#     '_id': '14817093',
#     '_score': 6.1670995,
#     '_source': {'author_name': 'Lewis, Samuel',
#      'title': 'The History and Topography of the Parish of Saint Mary, Islington, etc',
#      'country': 'England',
#      'language': 'English',
#      'year': 1842}},
#    {'_index': 'books',
#     '_id': '14891247',
#     '_score': 6.1384497,
#     '_source': {'author_name': 'Fryxell, Anders',
#      'title': 'The History of Sweden, translated from the original  edited by Mary Howitt',
#      'country': 'England',
#      'language': 'English',
#      'year': 1844}},
#    {'_index': 'books',
#     '_id': '14608667',
#     '_score': 6.09664,
#     '_source': {'author_name': 'Hughes, John, M.A., of Oriel College, Oxford',
#      'title': 'The Queen that Jack found. With thirteen cuts ... Sixth edition',
#      'country': 'England',
#      'language': 'English',
#      'year': 1820}},
#    {'_index': 'books',
#     '_id': '14610222',
#     '_score': 6.09664,
#     '_source': {'author_name': 'Snowden, Eleanor',
#      'title': 'The Moorish Queen: a Record of Pompeii; and other poems',
#      'country': 'England',
#      'language': 'English',
#      'year': 1831}},
#    {'_index': 'books',
#     '_id': '14643550',
#     '_score': 6.09664,
#     '_source': {'author_name': 'Robinson, Mary',
#      'title': 'Monody to the memory of the late Queen of France',
#      'country': 'England',
#      'language': 'English',
#      'year': 1793}},
#    {'_index': 'books',
#     '_id': '14824670',
#     '_score': 6.09664,
#     '_source': {'author_name': 'Warton, Thomas',
#      'title': 'Observations on the Fairy Queen of Spenser ... The second edition',
#      'country': 'England',
#      'language': 'English',
#      'year': 1807}},
#    {'_index': 'books',
#     '_id': '16288482',
#     '_score': 6.09664,
#     '_source': {'author_name': 'Spenser, Edmund',
#      'title': 'A new canto of Spencers Fairy Queen  . Now first published',
#      'country': 'England',
#      'language': 'English',
#      'year': 1747}},
#    {'_index': 'books',
#     '_id': '14830240',
#     '_score': 5.8963675,
#     '_source': {'author_name': 'Stocqueler, J. H. (Joachim Hayward)',
#      'title': 'Maid Marian, the Forest Queen, being a companion to Robin Hood.',
#      'country': 'England',
#      'language': 'English',
#      'year': 1849}},
#    {'_index': 'books',
#     '_id': '14939325',
#     '_score': 5.709359,
#     '_source': {'author_name': 'Andrews, Alexander',
#      'title': 'The Modern Antique: or the Muse in the costume of Queen Anne',
#      'country': 'England',
#      'language': 'English',
#      'year': 1813}},
#    {'_index': 'books',
#     '_id': '14602964',
#     '_score': 5.7017903,
#     '_source': {'author_name': 'Hull, Thomas',
#      'title': 'Mary; or, Female Friendship; a poem, in twelve books. By a Lady. Book the first',
#      'country': 'England',
#      'language': 'English',
#      'year': 1816}},
#    {'_index': 'books',
#     '_id': '14823818',
#     '_score': 5.7017903,
#     '_source': {'author_name': 'Robinson, Mary',
#      'title': 'The Poetical Works of the late Mrs. Mary Robinson, including many pieces never before published',
#      'country': 'England',
#      'language': 'English',
#      'year': 1806}},
#    {'_index': 'books',
#     '_id': '14608356',
#     '_score': 5.5343394,
#     '_source': {'author_name': 'Pepperpod, Peter, pseudonym',
#      'title': 'One Lay of a Night-Harper to his Queen  Edited by J. Senwood',
#      'country': 'England',
#      'language': 'English',
#      'year': 1820}},
#    {'_index': 'books',
#     '_id': '14768302',
#     '_score': 5.517404,
#     '_source': {'author_name': 'Wilson, Harrison Corbett',
#      'title': 'Englands Queen, and Prince Albert ... A poem in two cantos. ... Also Englands Hero, etc',
#      'country': 'England',
#      'language': 'English',
#      'year': 1849}},
#    {'_index': 'books',
#     '_id': '14796351',
#     '_score': 5.473785,
#     '_source': {'author_name': 'S, V.',
#      'title': 'A short Account of the Churches, Schools and Charities in the Parish of St. Mary, Rotherhithe',
#      'country': 'England',
#      'language': 'English',
#      'year': 1848}},
#    {'_index': 'books',
#     '_id': '14617129',
#     '_score': 5.4475975,
#     '_source': {'author_name': 'Ticklewig, Mary Ann',
#      'title': 'The Big Wigs Outwitted!! The extraordinary Trial of Miss Mary Ann Ticklewig; or, truth no libel',
#      'country': 'England',
#      'language': 'English',
#      'year': 1818}},
#    {'_index': 'books',
#     '_id': '14605700',
#     '_score': 5.39705,
#     '_source': {'author_name': 'Bacon, Robert, ll.d',
#      'title': 'Elegiac stanzas, inscribed to the memory of Mary Ann, the deceased wife of R. Bacon, etc',
#      'country': 'England',
#      'language': 'English',
#      'year': 1813}},
#    {'_index': 'books',
#     '_id': '14605670',
#     '_score': 5.385457,
#     '_source': {'author_name': 'Nugent, Robert Craggs, Earl Nugent',
#      'title': 'Verses addressed to the Queen, with a New Years gift of Irish manufacture ... Second edition',
#      'country': 'England',
#      'language': 'English',
#      'year': 1775}},
#    {'_index': 'books',
#     '_id': '14872234',
#     '_score': 5.3848586,
#     '_source': {'author_name': 'Lodge, Edmund, Norroy King of Arms',
#      'title': 'Illustrations of British History, Biography and Manners in the reigns of Henry VIII, Edward VI, Mary, Elizabeth, and James I. exhibited in a series of original papers, selected from the Manuscripts of the ... families of Howard, Talbot, and Cecil; containing ... a great part of the correspondence of Elizabeth and her ministers, with George, the sixth Earl of Shrewsbury, during the fifteen years in which Mary Queen of Scots remained in his custody; with numerous notes and observations ... with portraits',
#      'country': 'England',
#      'language': 'English',
#      'year': 1838}},
#    {'_index': 'books',
#     '_id': '14806284',
#     '_score': 5.370191,
#     '_source': {'author_name': 'Buist, James, of Perth',
#      'title': 'National Record of the Visit of Queen Victoria to Scotland in September, 1842, etc',
#      'country': 'England',
#      'language': 'English',
#      'year': 1842}},
#    {'_index': 'books',
#     '_id': '14813268',
#     '_score': 5.357749,
#     '_source': {'author_name': 'Heywood, Thomas, dramatist',
#      'title': 'If you know not me, you know no bodie: or the troubles of Queen Elizabeth',
#      'country': 'England',
#      'language': 'English',
#      'year': 1606}},
#    {'_index': 'books',
#     '_id': '14830119',
#     '_score': 5.3424263,
#     '_source': {'author_name': 'Stephens, George',
#      'title': 'Gertrude and Beatrice, or, the Queen of Hungary. A historical tragedy, in five acts',
#      'country': 'England',
#      'language': 'English',
#      'year': 1839}},
#    {'_index': 'books',
#     '_id': '14608783',
#     '_score': 5.1885486,
#     '_source': {'author_name': 'Pindar, Peter',
#      'title': 'The Cork Rump, or Queen and Maids of Honour. A poem  . By Peter Pindar Esq',
#      'country': 'England',
#      'language': 'English',
#      'year': 1815}},
#    {'_index': 'books',
#     '_id': '14608788',
#     '_score': 5.1885486,
#     '_source': {'author_name': 'Reynolds, Lancelot',
#      'title': 'A Panegyrick on ... Katherine, Queen of England, etc. or her Highness Cordiall Welcome into England',
#      'country': 'England',
#      'language': 'English',
#      'year': 1661}},
#    {'_index': 'books',
#     '_id': '14831531',
#     '_score': 5.1885486,
#     '_source': {'author_name': 'Waldron, Francis Godolphin',
#      'title': 'The Virgin Queen, a drama in five acts  : attempted as a sequel to Shakspeares Tempest',
#      'country': 'England',
#      'language': 'English',
#      'year': 1797}},
#    {'_index': 'books',
#     '_id': '14831950',
#     '_score': 5.1885486,
#     '_source': {'author_name': 'Weston, John, dramatist',
#      'title': 'The Amazon Queen; or, The Amours of Thalestris to Alexander the Great. A tragi-comedy',
#      'country': 'England',
#      'language': 'English',
#      'year': 1667}},
#    {'_index': 'books',
#     '_id': '14830647',
#     '_score': 5.1126184,
#     '_source': {'author_name': 'Taylor, William, antiquary',
#      'title': 'Annals of St. Mary Overy; an historical and descriptive account of St. Saviours Church and Parish. With illustrations',
#      'country': 'England',
#      'language': 'English',
#      'year': 1833}},
#    {'_index': 'books',
#     '_id': '16288934',
#     '_score': 5.1121793,
#     '_source': {'author_name': 'Wheeler, Clifford',
#      'title': 'A Sweet Homily ... Sonnets, done in the style ... of Shakespeare (composed in honour of the nuptials of Princess Mary)',
#      'country': 'England',
#      'language': 'English',
#      'year': 1922}},
#    {'_index': 'books',
#     '_id': '14616979',
#     '_score': 5.043699,
#     '_source': {'author_name': 'Philalethes, Theophilos, pseudonym',
#      'title': 'Songs, duets, and dramatic pieces in the comic opera of Philandering, or, the Rose Queen, etc',
#      'country': 'England',
#      'language': 'English',
#      'year': 1824}},
#    {'_index': 'books',
#     '_id': '14809490',
#     '_score': 4.9590282,
#     '_source': {'author_name': 'Dryden, John',
#      'title': 'Secret-love, or The maiden-queen: as it is acted by His Majesties Servants, at the Theater-Royal',
#      'country': 'England',
#      'language': 'English',
#      'year': 1735}},
#    {'_index': 'books',
#     '_id': '14767914',
#     '_score': 4.9337106,
#     '_source': {'author_name': 'Chapel of the Savoy (London)',
#      'title': 'Notice on the Savoy Chapel, built by King Henry VII. and recently restored by Queen Victoria, 1844',
#      'country': 'England',
#      'language': 'English',
#      'year': 1844}},
#    {'_index': 'books',
#     '_id': '14809478',
#     '_score': 4.931895,
#     '_source': {'author_name': 'Dryden, John',
#      'title': 'The Indian Emperour, or, The conquest of Mexico by the Spaniards. Being the sequel of the Indian Queen',
#      'country': 'England',
#      'language': 'English',
#      'year': 1667}},
#    {'_index': 'books',
#     '_id': '14823045',
#     '_score': 4.925742,
#     '_source': {'author_name': 'London, Kensington, Parish of St. Mary Abbots',
#      'title': 'Diagrams of the parish of Saint Mary Abbotts, Kensington: published under the authority of the Board of Trustees, October 1846',
#      'country': 'England',
#      'language': 'English',
#      'year': 1847}},
#    {'_index': 'books',
#     '_id': '14809489',
#     '_score': 4.8042955,
#     '_source': {'author_name': 'Dryden, John',
#      'title': 'Secret-love, or The maiden-queen: as it is acted by His Majesties Servants, at the Theater-Royal',
#      'country': 'England',
#      'language': 'English',
#      'year': 1669}},
#    {'_index': 'books',
#     '_id': '14814741',
#     '_score': 4.8042955,
#     '_source': {'author_name': 'Jones, Joshua, of Bristol',
#      'title': 'Further report on the accounts of the Corporation of Bristol, as the late Governors of Queen Elizabeths Hospital',
#      'country': 'England',
#      'language': 'English',
#      'year': 1840}},
#    {'_index': 'books',
#     '_id': '14829434',
#     '_score': 4.6560097,
#     '_source': {'author_name': 'Shelley, Percy Bysshe',
#      'title': 'Reply to the Anti-matrimonial hypothesis and supposed atheism of P. B. Shelley, as laid down in Queen Mab',
#      'country': 'England',
#      'language': 'English',
#      'year': 1821}},
#    {'_index': 'books',
#     '_id': '14610203',
#     '_score': 4.5657926,
#     '_source': {'author_name': 'Christ Church (University of Oxford)',
#      'title': 'Speeches spoken to the King and Queen, Duke and Duchesse of York, in Christ-Church Hall, Oxford. Sept. 29, 1663',
#      'country': 'England',
#      'language': 'English',
#      'year': 1663}},
#    {'_index': 'books',
#     '_id': '14603283',
#     '_score': 4.489508,
#     '_source': {'author_name': 'Yearsley, Ann',
#      'title': 'An Elegy on Marie Antoinette, ... Queen of France. With a poem on the last interview between the King of Poland and Loraski',
#      'country': 'England',
#      'language': 'English',
#      'year': 1795}},
#    {'_index': 'books',
#     '_id': '14841124',
#     '_score': 4.421095,
#     '_source': {'author_name': 'Roper, Samuel',
#      'title': 'A statistical account of the Hackney District, comprising the parishes of St. John at Hackney, and St. Mary, Stoke Newington, during the year 1841',
#      'country': 'England',
#      'language': 'English',
#      'year': 1844}},
#    {'_index': 'books',
#     '_id': '14871281',
#     '_score': 4.36039,
#     '_source': {'author_name': 'Botta, Carlo',
#      'title': 'History of Italy during the Consulate and Empire of Napoleon Buonaparte. Translated ... by the author of The Life of Joanna, Queen of Naples',
#      'country': 'England',
#      'language': 'English',
#      'year': 1828}},
#    {'_index': 'books',
#     '_id': '14879533',
#     '_score': 4.2271485,
#     '_source': {'author_name': 'Botta, Carlo',
#      'title': 'History of Italy during the Consulate and Empire of Napoleon Buonaparte. Translated ... by the author of The Life of Joanna, Queen of Naples',
#      'country': 'England',
#      'language': 'English',
#      'year': 1829}},
#    {'_index': 'books',
#     '_id': '14891349',
#     '_score': 4.1944532,
#     '_source': {'author_name': 'Hughes, T. S. (Thomas Smart)',
#      'title': 'The History of England, from the accession of George III. to the accession of Queen Victoria. Third edition, to which is prefixed a preliminary essay',
#      'country': 'England',
#      'language': 'English',
#      'year': 1846}},
#    {'_index': 'books',
#     '_id': '14896478',
#     '_score': 4.105007,
#     '_source': {'author_name': 'Hervey, John Hervey, Baron',
#      'title': 'Memoirs of the Reign of George the Second, from his accession to the death of Queen Caroline. Edited, from the original manuscript by J. W. Croker',
#      'country': 'England',
#      'language': 'English',
#      'year': 1848}},
#    {'_index': 'books',
#     '_id': '14610175',
#     '_score': 4.0661573,
#     '_source': {'author_name': 'Hawker, Robert Stephen',
#      'title': 'A welcome to the Prince Albert, submitted to the Queen on the approach of her Majestys Marriage by the author of Pompeii (R. S. H.)',
#      'country': 'England',
#      'language': 'English',
#      'year': 1840}},
#    {'_index': 'books',
#     '_id': '14885090',
#     '_score': 4.01952,
#     '_source': {'author_name': 'Barlace, James George',
#      'title': 'An Historical Sketch of the Progress of Knowledge in England, from the conversion of the Anglo-Saxons, to the end of the reign of Queen Elisabeth  L.P',
#      'country': 'England',
#      'language': 'English',
#      'year': 1819}},
#    {'_index': 'books',
#     '_id': '14940032',
#     '_score': 3.9944825,
#     '_source': {'author_name': 'Wade, John, Vice-President of the Historical Section of the Institut dAfrique of Paris',
#      'title': 'British history, chronologically arranged, comprehending a classified analysis of events ... in Church and State, from the first invasion by the Romans to the accession of Queen Victoria',
#      'country': 'England',
#      'language': 'English',
#      'year': 1844}},
#    {'_index': 'books',
#     '_id': '14822981',
#     '_score': 3.9129348,
#     '_source': {'author_name': 'Fardell, John George',
#      'title': 'Extracts from Wills and other Documents containing Benefactions to the Town of Faversham. Including a translation of the foundation charter of the Free Grammar School of Queen Elizabeth',
#      'country': 'England',
#      'language': 'English',
#      'year': 1844}},
#    {'_index': 'books',
#     '_id': '14873073',
#     '_score': 3.8743734,
#     '_source': {'author_name': 'Wade, John, Vice-President of the Historical Section of the Institut dAfrique of Paris',
#      'title': 'British history, chronologically arranged, comprehending a classified analysis of events ... in Church and State, from the first invasion by the Romans to the accession of Queen Victoria',
#      'country': 'England',
#      'language': 'English',
#      'year': 1839}},
#    {'_index': 'books',
#     '_id': '14822936',
#     '_score': 3.8275025,
#     '_source': {'author_name': 'Cotton, William, F.S.A., of Ivybridge',
#      'title': 'The Coventry Guide, containing a concise account of the ancient history of the city, and particular descriptions of the churches, St. Mary Hall, and other public buildings. Illustrated with eight engravings',
#      'country': 'England',
#      'language': 'English',
#      'year': 1824}},
#    {'_index': 'books',
#     '_id': '14603462',
#     '_score': 3.7843482,
#     '_source': {'author_name': 'Charles, I., King of England',
#      'title': 'Two Copies of Verses, on the Meeting of King Charles the First and his Queen Henrietta-Maria, in the Valley of Kineton, below Edge-Hill, in Warwickshire, July 13, 1643',
#      'country': 'England',
#      'language': 'English',
#      'year': 1822}},
#    {'_index': 'books',
#     '_id': '14806919',
#     '_score': 3.7843482,
#     '_source': {'author_name': 'Caröe, William Douglas',
#      'title': 'Voyages and Travels of Her Majesty, Caroline Queen of Great Britain: including visits to various parts of Germany, France, Italy, Greece, Palestine, &c. ... By one of Her Majestys suite , etc',
#      'country': 'England',
#      'language': 'English',
#      'year': 1821}},
#    {'_index': 'books',
#     '_id': '14829974',
#     '_score': 3.7426693,
#     '_source': {'author_name': 'Spenser, Edmund',
#      'title': 'The Progress of Time; or, an emblematical representation of the Four Seasons and Twelve Months, as marching in procession round their annual circle. In imitation of Spencers Fairy Queen',
#      'country': 'England',
#      'language': 'English',
#      'year': 1749}},
#    {'_index': 'books',
#     '_id': '14610156',
#     '_score': 3.5530934,
#     '_source': {'author_name': 'Caroline, Queen, consort of George Iv, King of Great Britain',
#      'title': 'The Royal Letter-Bag; containing familiar epistles from royal personages, ministers of state, bishops, generals, discarded mistresses, Italian witnesses, &c, &c, relative to the Queen and other important state affairs. Second edition, etc',
#      'country': 'England',
#      'language': 'English',
#      'year': 1820}},
#    {'_index': 'books',
#     '_id': '14818360',
#     '_score': 3.5128524,
#     '_source': {'author_name': 'Manship, Henry, the Elder',
#      'title': 'A Booke of the Foundacion and Antiquitye of the Towne of Greate Yermouthe: from the original manuscript written in the time of Queen Elizabeth, with Notes and an Appendix. Edited by C. J. Palmer',
#      'country': 'England',
#      'language': 'English',
#      'year': 1847}},
#    {'_index': 'books',
#     '_id': '14879650',
#     '_score': 3.4973853,
#     '_source': {'author_name': 'Davie, John Constanse',
#      'title': 'Letters from Paraguay: describing the settlements of Monte Video and Buenos Ayres; the presidencies of Rioja Minor, Nombre de Dios, St. Mary and St. John ... with the manners, customs, religious ceremonies, &c. of the inhabitants, etc',
#      'country': 'England',
#      'language': 'English',
#      'year': 1805}},
#    {'_index': 'books',
#     '_id': '14628895',
#     '_score': 3.3873825,
#     '_source': {'author_name': 'Palmer, W., Lessee of Royalty Theatre',
#      'title': 'Lecture on Heads , as delivered by Mr. Palmer ... A Picture of the Playhouse, or Bucks, have at ye all. By Mr. Palmer. The Golden Days of good Queen Bess! written by Mr. Collins, etc',
#      'country': 'England',
#      'language': 'English',
#      'year': 1787}},
#    {'_index': 'books',
#     '_id': '14826289',
#     '_score': 3.3538284,
#     '_source': {'author_name': 'Nelson, John, of Islington',
#      'title': 'The history, topography and antiquities of the parish of St. Mary Islington, in the county of Middlesex : including biographical sketches of the most eminent and remarkable persons who have been born, or have resided there ; illustrated by seventeen engravings',
#      'country': 'England',
#      'language': 'English',
#      'year': 1811}},
#    {'_index': 'books',
#     '_id': '14622969',
#     '_score': 3.0795958,
#     '_source': {'author_name': 'Smith, John, of Cookley',
#      'title': 'Brownrigg the Second; or the Cruel Stepmother. The full particulars of the trial of John and Elizabeth Smith ... for the murder of Mary Ann Smith. ... To which is added the trial and execution of Edmund Thrower, for the murder of Thomas Carter and Elizabeth Carter',
#      'country': 'England',
#      'language': 'English',
#      'year': 1812}},
#    {'_index': 'books',
#     '_id': '14628958',
#     '_score': 3.056336,
#     '_source': {'author_name': 'Waldron, Francis Godolphin',
#      'title': 'Free reflections on miscellaneous papers and legal instruments,  under the hand and seal of W. Shakspeare, in the possession of S. Ireland;  ... To which are added, extracts from an unpublished MS. play, called The Virgin Queen, written by, or in imitation of, Shakespeare',
#      'country': 'England',
#      'language': 'English',
#      'year': 1796}},
#    {'_index': 'books',
#     '_id': '14831232',
#     '_score': 2.9014127,
#     '_source': {'author_name': 'Tytler, Robert',
#      'title': 'Illustrations of ancient geography and history; referring to the sites of Ophir, Sheba, Taprobane, the Aurea Chersonesus, and other scriptural and classical cities and subjects: elucidating, also, the visit of the Queen of Sheba to Solomon, at Jerusalem, derived from recent investigations in the Eastern Indian Archipelago',
#      'country': 'England',
#      'language': 'English',
#      'year': 1825}},
#    {'_index': 'books',
#     '_id': '14806920',
#     '_score': 2.8821545,
#     '_source': {'author_name': 'Caröe, William Douglas',
#      'title': 'Voyages and Travels of Her Majesty, Caroline Queen of Great Britain: including visits to various parts of Germany, France, Italy, Greece, Palestine, &c. ... and comprising the latest description of those ... countries ... By one of Her Majestys suite  . The whole embellished with picturesque views, &c',
#      'country': 'England',
#      'language': 'English',
#      'year': 1823}}]}}

# %%
# SOLUTION TO EXERCISE F

query ={
  "query": {
    "fuzzy": {
      "title": {
        "value": "comander",
        "fuzziness": "AUTO",
        "max_expansions": 50,
        "prefix_length": 0,
        "transpositions": True,
        "rewrite": "constant_score"
      }
    }
  }
}
r = e.curl('get', f'books/_search', query)
r.json()
# Out:
# {'took': 8,
#  'timed_out': False,
#  '_shards': {'total': 4, 'successful': 4, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 64, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'books',
#     '_id': '14603267',
#     '_score': 1.0,
#     '_source': {'author_name': 'Pindar, Peter, Jun, pseudonym [i.e. John Agg]',
#      'title': 'Three R----l Bloods; or, a Lame r-t, a darling commander, and a love-sick admiral. A poem. By Peter Pindar, Jun. (Seventh edition.)',
#      'country': 'England',
#      'language': 'English',
#      'year': 1812}},
#    {'_index': 'books',
#     '_id': '14809925',
#     '_score': 1.0,
#     '_source': {'author_name': 'Elliott, Robert, Commander, R.N.',
#      'title': 'Views in India, China, and on the Shores of the Red Sea: drawn by Prout, Stanfield, Cattermole, Purser, Cox, Austen, &c. from original sketches by Commander R. Elliott ... With descriptions by Emma Roberts',
#      'country': 'England',
#      'language': 'English',
#      'year': 1835}},
#    {'_index': 'books',
#     '_id': '14810095',
#     '_score': 1.0,
#     '_source': {'author_name': 'Great Britain, Hydrographic Department',
#      'title': 'Report on the Bore of the Tsien-Tang Kiang, by Commander Moore',
#      'country': 'England',
#      'language': 'English',
#      'year': 1888}},
#    {'_index': 'books',
#     '_id': '14812111',
#     '_score': 1.0,
#     '_source': {'author_name': 'Graydon, William Murray',
#      'title': 'The Logs of the First Voyage, made with the unceasing aid of steam, between England and America, by the Great Western, of Bristol, Lieut. James Hosken, R.N, Commander; also an appendix and remarks, by Christopher Claxton',
#      'country': 'England',
#      'language': 'English',
#      'year': 1838}},
#    {'_index': 'books',
#     '_id': '14814786',
#     '_score': 1.0,
#     '_source': {'author_name': 'Jukes, Joseph Beete',
#      'title': 'Narrative of the surveying voyage of H.M.S. Fly; commanded by Capt. F. P. Blackwood in Torres Strait, New Guinea, and other Islands of the Eastern Archipelago, 1842-1846, together with an excursion into the interior of the Eastern part of Java',
#      'country': 'England',
#      'language': 'English',
#      'year': 1847}},
#    {'_index': 'books',
#     '_id': '14830619',
#     '_score': 1.0,
#     '_source': {'author_name': 'Taylor, Fitch Waterman',
#      'title': 'A Voyage round the World and visits to various foreign countries in the United States frigate Columbia, attended by her consort the sloop of war John Adams, and commanded by G. C. Read. ... Third edition',
#      'country': 'United States of America',
#      'language': 'English',
#      'year': 1843}},
#    {'_index': 'books',
#     '_id': '14831474',
#     '_score': 1.0,
#     '_source': {'author_name': 'Wrangel, Ferdinand Petrovich, Baron',
#      'title': 'Narrative of an Expedition to the Polar Sea, in the years 1820, 1821, 1822 and 1823: commanded by ... F. von Wrangell  Edited by E. Sabine',
#      'country': 'England',
#      'language': 'English',
#      'year': 1840}},
#    {'_index': 'books',
#     '_id': '14839918',
#     '_score': 1.0,
#     '_source': {'author_name': 'Great Britain, Hydrographic Department',
#      'title': 'The China Sea Directory. Vol. II. ... Compiled in the Hydrographic Department, Admiralty. Third edition. (The present edition revised by Commander C. F. Oldham; prepared for press by Captain J. J. P. Hitchfield.)',
#      'country': 'England',
#      'language': 'English',
#      'year': 1889}},
#    {'_index': 'books',
#     '_id': '14839919',
#     '_score': 1.0,
#     '_source': {'author_name': 'Great Britain, Hydrographic Department',
#      'title': 'The China Sea Directory. Vol. III. ... Third edition. Compiled from various sources (by Staff-Commander W. H. Petley)',
#      'country': 'England',
#      'language': 'English',
#      'year': 1894}},
#    {'_index': 'books',
#     '_id': '14847206',
#     '_score': 1.0,
#     '_source': {'author_name': 'Great Britain, Hydrographic Department',
#      'title': 'The China Sea Directory, vol. I. Containing directions for the approaches to the China Sea and to Singapore, by the straits of Sunda, Banka, Gaspar, Carimata, Rhio, Varella, Durian, and Singapore. Compiled from various sources partly by J. W. Reed ... Completed and edited by Staff Commander J. W. King',
#      'country': 'England',
#      'language': 'English',
#      'year': 1867}}]}}

# %%
# SOLUTION TO EXERCISE G

# https://www.elastic.co/guide/en/elasticsearch/reference/current/docs-termvectors.html
query = {
    "fields" : ["title"],
    "term_statistics" : True,
    "field_statistics" : True,
    "positions": True,
    "filter": {
        "min_word_length": 4,
        "min_term_freq" : 2
  }
}
#r = e.curl('get', f'books/_doc/{doc_ids[4200]}')
r = e.curl('get', f'books/_termvectors/{doc_ids[4200]}', query)
r.json()
# Out:
# {'_index': 'books',
#  '_id': '14767985',
#  '_version': 1,
#  'found': True,
#  'took': 4,
#  'term_vectors': {'title': {'field_statistics': {'sum_doc_freq': 148337,
#     'doc_count': 13216,
#     'sum_ttf': 166497},
#    'terms': {'with': {'doc_freq': 1908,
#      'ttf': 2076,
#      'term_freq': 2,
#      'tokens': [{'position': 9, 'start_offset': 52, 'end_offset': 56},
#       {'position': 24, 'start_offset': 135, 'end_offset': 139}],
#      'score': 5.8698487}}}}}
