# %% [markdown]
# ## Imports and data loading

# %%
import math
import random
import time

import pandas as pd
import numpy as np

from scipy import sparse
from scipy.sparse import csr_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity

from sparselsh import LSH

# %% [markdown]
# ## Content-based, regression

# %%
# load food.com data
directory = 'data/food.com'
df_recipe_rating = pd.read_csv(f'{directory}/recipe_ratings.csv')
df_recipe = pd.read_csv(f'{directory}/recipe.csv')

# %%
df_recipe.head()
# Out:
#    recipe_id                                        name  minutes  n_steps  \
# 0     137739  arriba   baked winter squash mexican style       55       11
# 1      31490            a bit different  breakfast pizza       30        9
# 2     112140                   all in the kitchen  chili      130        6
# 3      59389                          alouette  potatoes       45       11
# 4      44061          amish  tomato ketchup  for canning      190        5
#
#    n_ingredients  calories   fat  sugar  sodium  protein  saturated  carbs
# 0              7      51.5   0.0   13.0     0.0      2.0        0.0    4.0
# 1              6     173.4  18.0    0.0    17.0     22.0       35.0    1.0
# 2             13     269.8  22.0   32.0    48.0     39.0       27.0    5.0
# 3             11     368.1  17.0   10.0     2.0     14.0        8.0   20.0
# 4              8     352.9   1.0  337.0    23.0      3.0        0.0   28.0

# %%
df_recipe_rating
# Out:
#            user_id  recipe_id  rating
# 0             2046       4684     5.0
# 1             2046        517     5.0
# 2             1773       7435     5.0
# 3             1773        278     4.0
# 4             2046       3431     5.0
# ...            ...        ...     ...
# 698896      926904     457971     5.0
# 698897  2002312797      27208     5.0
# 698898     1290903     131607     5.0
# 698899      226867     363072     5.0
# 698900  2000498330     314535     5.0
#
# [698901 rows x 3 columns]

# %%
#EXERCISE: Build a content-based recommender system that uses linear regression 
#          to predict ratings.
#          Try it out on users with a high number of ratings.
#          Try some train-test split to evaluate performance.

#select the ratings of a specific user 


sorted_users = df_recipe_rating.groupby(["user_id"]).agg(count=("user_id", "count")).sort_values("count", ascending=False)
target_id = sorted_users.index[0]
df_user = df_recipe_rating[df_recipe_rating['user_id']==target_id][['recipe_id','rating']]
df_rec = pd.merge(df_user, df_recipe, on='recipe_id', how='inner')



# define features
features = ["minutes", 
            "n_steps", 
            "n_ingredients", 
            "calories", 
            "fat", 
            "sugar",
            "sodium",
            "protein",
            "saturated",
            "carbs"
        ] 

# split training and test
x = df_rec.drop(["recipe_id" , "name"], axis=1)
y = df_rec["rating"]
x_train, x_test, y_train, y_test = train_test_split(x, y, shuffle=True)


model = LinearRegression();

predicted = model.fit(x_train, y_train).predict(x_test)


expected = []
for index, row in x_test.iterrows():
    expected.append(row['rating'])

mse = (np.square(expected - predicted)).mean()

print(f"mse:  {mse}")

# ...
# Out:
# mse:  3.2700507195907956e-31

# %% [markdown]
# ## Content-based, KNN (with LSH)

# %%
directory = 'data/movielens/ml-latest-small'
#directory = 'data/movielens/ml-latest' #change into this one for the full dataset (slow)

df_movies = pd.read_csv(f'{directory}/movies.csv')
df_ratings = pd.read_csv(f'{directory}/ratings.csv')
df_tags = pd.read_csv(f'{directory}/tags.csv')

#transform tags such that they are lower-case, single-word tokens
df_tags['tag'] = df_tags['tag'].apply(lambda x: str(x).lower().replace(' ', '_'))

# %%
df_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  highly_quotable  1445714996
# 2       2    60756     will_ferrell  1445714992
# 3       2    89774     boxing_story  1445715207
# 4       2    89774              mma  1445715200

# %% [markdown]
# ### Step1: Calculate item profiles

# %%
# calculates the lexicon of most frequent tags.
tag_frequency_threshold = 5 # increase number to filter
# sorted_users = df_recipe_rating.groupby(["user_id"]).agg(count=("user_id", "count")).sort_values("count", ascending=False)
df_lexicon = df_tags.groupby("tag").agg(count=("tag", "count")) # get a dataframe with tags and respective counts
# discard movies with no tags
item_profiles = df_movies[df_movies["movieId"].isin(df_tags["movieId"])]
item_profiles
# you can drop the userId and timestamp columns because we don't care who assigned the tag and when
# ...
# Out:
#       movieId                               title  \
# 0           1                    Toy Story (1995)
# 1           2                      Jumanji (1995)
# 2           3             Grumpier Old Men (1995)
# 4           5  Father of the Bride Part II (1995)
# 6           7                      Sabrina (1995)
# ...       ...                                 ...
# 9681   183611                   Game Night (2018)
# 9692   184471                  Tomb Raider (2018)
# 9709   187593                   Deadpool 2 (2018)
# 9710   187595      Solo: A Star Wars Story (2018)
# 9732   193565           Gintama: The Movie (2010)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 4                                          Comedy
# 6                                  Comedy|Romance
# ...                                           ...
# 9681                   Action|Comedy|Crime|Horror
# 9692                     Action|Adventure|Fantasy
# 9709                         Action|Comedy|Sci-Fi
# 9710             Action|Adventure|Children|Sci-Fi
# 9732               Action|Animation|Comedy|Sci-Fi
#
# [1572 rows x 3 columns]

# %%
#calculate the sparse feature vector based on the TF-IDF of words in documents
#the TF-IDF vectors are saved as sparse representations into the dataframe
df_features = df_tags.groupby('movieId').agg(lambda x: ' '.join(x)).reset_index()
vectorizer = TfidfVectorizer(tokenizer=lambda x: x.split(' ')).fit(sorted(df_features['tag']))
vectorizer.vocabulary_
df_features['feature_vector'] = df_features['tag'].apply(lambda x : vectorizer.transform([x]))
df_features
# Out:
# /var/folders/m5/l9b6fpv12v370f32ct4y00h00000gn/T/ipykernel_7469/2621643708.py:3: FutureWarning: ['userId', 'timestamp'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_features = df_tags.groupby('movieId').agg(lambda x: ' '.join(x)).reset_index()
# /Users/alexanderwermuth/opt/anaconda3/envs/data-in-production/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
#       movieId                                              tag  \
# 0           1                                  pixar pixar fun
# 1           2     fantasy magic_board_game robin_williams game
# 2           3                                        moldy old
# 3           5                                 pregnancy remake
# 4           7                                           remake
# ...       ...                                              ...
# 1567   183611                      comedy funny rachel_mcadams
# 1568   184471  adventure alicia_vikander video_game_adaptation
# 1569   187593                josh_brolin ryan_reynolds sarcasm
# 1570   187595                          emilia_clarke star_wars
# 1571   193565                    anime comedy gintama remaster
#
#                                          feature_vector
# 0       (0, 1016)\t0.8992312620852461\n  (0, 513)\t0...
# 1       (0, 1129)\t0.48431677463057304\n  (0, 812)\t...
# 2       (0, 967)\t0.7071067811865475\n  (0, 876)\t0....
# 3       (0, 1106)\t0.6808321878901952\n  (0, 1044)\t...
# 4                                        (0, 1106)\t1.0
# ...                                                 ...
# 1567    (0, 1084)\t0.7153847877740599\n  (0, 515)\t0...
# 1568    (0, 1418)\t0.6173008972335793\n  (0, 46)\t0....
# 1569    (0, 1156)\t0.5453455400986055\n  (0, 1147)\t...
# 1570    (0, 1266)\t0.6876494487057803\n  (0, 433)\t0...
# 1571    (0, 1107)\t0.5715745894656075\n  (0, 536)\t0...
#
# [1572 rows x 3 columns]

# %% [markdown]
# ### Step2: Index item profiles into LSH

# %%
m = sparse.vstack(df_features["feature_vector"])
#index all item vectors into LSH
lsh = LSH(4, m.shape[1], num_hashtables=1, storage_config={"dict":None})
#run an example query to the LSH
lsh.index(m, df_features["movieId"])
query = np.zeros(m.shape[1])
query[0] = 1
lsh.query(csr_matrix(query))
# Out:
# [((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 3 stored elements in Compressed Sparse Row format>,
#    150),
#   1.9999999999999996),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 7 stored elements in Compressed Sparse Row format>,
#    38061),
#   1.9999999999999996),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 3 stored elements in Compressed Sparse Row format>,
#    176419),
#   1.9999999999999998),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 4 stored elements in Compressed Sparse Row format>,
#    111743),
#   1.9999999999999998),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 9 stored elements in Compressed Sparse Row format>,
#    87430),
#   1.9999999999999998),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 2 stored elements in Compressed Sparse Row format>,
#    2431),
#   1.9999999999999998),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 4 stored elements in Compressed Sparse Row format>,
#    8961),
#   1.9999999999999998),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    6963),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    6970),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    7023),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    7025),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    7071),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    7088),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    7121),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    7141),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    7218),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    6786),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    7234),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    7439),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    7700),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    7748),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    7792),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    7924),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    7926),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    8014),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    7190),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    6773),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    6713),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    6724),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    4969),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    5120),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    5224),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    5238),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 3 stored elements in Compressed Sparse Row format>,
#    5291),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    5304),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    5475),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    5498),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    5633),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    5747),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    6027),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    6041),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 2 stored elements in Compressed Sparse Row format>,
#    6157),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    6228),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    6244),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    6452),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    6466),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    6516),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    6660),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    6668),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    8033),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    6744),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    8094),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    8197),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    8190),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    32160),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    32371),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    34437),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    34482),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    36535),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    37240),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    37733),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 2 stored elements in Compressed Sparse Row format>,
#    39234),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    40583),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    31923),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    40629),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    42002),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    42740),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 7 stored elements in Compressed Sparse Row format>,
#    45730),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 3 stored elements in Compressed Sparse Row format>,
#    58295),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 2 stored elements in Compressed Sparse Row format>,
#    62434),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 8 stored elements in Compressed Sparse Row format>,
#    69757),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    82242),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 6 stored elements in Compressed Sparse Row format>,
#    119141),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 2 stored elements in Compressed Sparse Row format>,
#    126548),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    41997),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 3 stored elements in Compressed Sparse Row format>,
#    30892),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    27741),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    27731),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    4787),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    8207),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    8275),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    8337),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    8379),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    8507),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    8607),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    8609),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    8638),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    8754),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    8765),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    8838),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    8920),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    8943),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    8998),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    25855),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    25865),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    25952),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    26131),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    26242),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    26776),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    8183),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    4688),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 2 stored elements in Compressed Sparse Row format>,
#    3),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    4477),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    1041),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 2 stored elements in Compressed Sparse Row format>,
#    1084),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    1135),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 2 stored elements in Compressed Sparse Row format>,
#    1147),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 2 stored elements in Compressed Sparse Row format>,
#    1178),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    1185),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    1204),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    1277),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    1280),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 2 stored elements in Compressed Sparse Row format>,
#    1301),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    1361),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    1398),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 2 stored elements in Compressed Sparse Row format>,
#    1441),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    1446),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    1542),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    1586),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 2 stored elements in Compressed Sparse Row format>,
#    1643),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    1650),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    1663),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    1672),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    1674),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    976),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    1683),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    930),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    800),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 8 stored elements in Compressed Sparse Row format>,
#    32),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    111),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    160),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    162),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    215),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 2 stored elements in Compressed Sparse Row format>,
#    224),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    232),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    246),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    261),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    279),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    290),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    326),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 2 stored elements in Compressed Sparse Row format>,
#    425),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    474),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    516),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    529),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    531),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    543),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 8 stored elements in Compressed Sparse Row format>,
#    589),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 2 stored elements in Compressed Sparse Row format>,
#    590),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    728),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    912),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    156371),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 2 stored elements in Compressed Sparse Row format>,
#    1726),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    1893),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    3263),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    3338),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    3360),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    3456),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    3498),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    3507),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    3548),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 3 stored elements in Compressed Sparse Row format>,
#    3556),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    3559),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 3 stored elements in Compressed Sparse Row format>,
#    3671),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 5 stored elements in Compressed Sparse Row format>,
#    3793),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    3951),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    3967),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    4117),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    4174),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    4194),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    4218),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    4262),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    4312),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    4356),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    4404),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    3250),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    1797),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    3192),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 2 stored elements in Compressed Sparse Row format>,
#    3077),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    1900),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    1902),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    1917),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    2065),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 2 stored elements in Compressed Sparse Row format>,
#    2071),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 2 stored elements in Compressed Sparse Row format>,
#    2268),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    2351),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    2360),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    2390),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    2442),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    3152),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    4545),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    2616),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    2648),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    2677),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 2 stored elements in Compressed Sparse Row format>,
#    2761),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    2863),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    2905),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    2939),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 2 stored elements in Compressed Sparse Row format>,
#    3006),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    3007),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    3060),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 1 stored elements in Compressed Sparse Row format>,
#    2505),
#   2.0),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 3 stored elements in Compressed Sparse Row format>,
#    8533),
#   2.0000000000000004),
#  ((<1x1475 sparse matrix of type '<class 'numpy.float64'>'
#    	with 17 stored elements in Compressed Sparse Row format>,
#    3676),
#   2.0000000000000004)]

# %% [markdown]
# ### Step 3: Calculate user profile

# %%
# restricts the ratings to the set of most popular movies (optional, not needed for content-based)
numratings_threshold = 0 #increase this number if you want to filter
df_item_popularity = df_ratings[['movieId','rating']].groupby('movieId').count().reset_index()
df_item_popularity.columns = ['movieId','count'] 
df_item_popularity = df_item_popularity.sort_values(by='count', ascending=False)
df_item_popularity = df_item_popularity[df_item_popularity['count'] >= numratings_threshold]
print(f'Number of movies reduced from {len(df_ratings.movieId.unique())} to {len(df_item_popularity.movieId.unique())}')
df_ratings = pd.merge(df_ratings, df_item_popularity, on='movieId', how='inner')[['userId', 'movieId', 'rating']]
df_ratings = df_ratings.sort_values(by='userId')

#rescale the ratings by the user's individual average 
df_ratings['rating_scaled'] = ...

df_ratings.head()
# Out:
# Number of movies reduced from 9724 to 9724
#        userId  movieId  rating rating_scaled
# 0           1        1     4.0      Ellipsis
# 12117       1     2389     2.0      Ellipsis
# 12126       1     2395     5.0      Ellipsis
# 12182       1     2406     4.0      Ellipsis
# 776         1       70     3.0      Ellipsis

# %%
# join ratings with movie feature vectors
df_profile = pd.merge(df_ratings, df_features[['movieId','feature_vector']],
              on='movieId')
#scaling feature vector by rating (this will take a few minutes)
df_profile['feature_vector_scaled'] = df_profile['rating_scaled'] * df_profile['feature_vector']
df_profile
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/envs/data-in-production/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:165, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 try:
# --> 165     result = func(left, right)
#     166 except TypeError:
#
# File ~/opt/anaconda3/envs/data-in-production/lib/python3.10/site-packages/pandas/core/computation/expressions.py:241, in evaluate(op, a, b, use_numexpr)
#     239     if use_numexpr:
#     240         # error: "None" not callable
# --> 241         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242 return _evaluate_standard(op, op_str, a, b)
#
# File ~/opt/anaconda3/envs/data-in-production/lib/python3.10/site-packages/pandas/core/computation/expressions.py:129, in _evaluate_numexpr(op, op_str, a, b)
#     128 if result is None:
# --> 129     result = _evaluate_standard(op, op_str, a, b)
#     131 return result
#
# File ~/opt/anaconda3/envs/data-in-production/lib/python3.10/site-packages/pandas/core/computation/expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      69     _store_test_result(False)
# ---> 70 return op(a, b)
#
# File ~/opt/anaconda3/envs/data-in-production/lib/python3.10/site-packages/scipy/sparse/_base.py:620, in spmatrix.__rmul__(self, other)
#     619 def __rmul__(self, other):  # other * self
# --> 620     return self._rmul_dispatch(other)
#
# File ~/opt/anaconda3/envs/data-in-production/lib/python3.10/site-packages/scipy/sparse/_base.py:614, in spmatrix._rmul_dispatch(self, other)
#     613     tr = np.asarray(other).transpose()
# --> 614 ret = self.transpose()._mul_dispatch(tr)
#     615 if ret is NotImplemented:
#
# File ~/opt/anaconda3/envs/data-in-production/lib/python3.10/site-packages/scipy/sparse/_base.py:536, in spmatrix._mul_dispatch(self, other)
#     534 if isscalarlike(other):
#     535     # scalar value
# --> 536     return self._mul_scalar(other)
#     538 if issparse(other):
#
# File ~/opt/anaconda3/envs/data-in-production/lib/python3.10/site-packages/scipy/sparse/_data.py:124, in _data_matrix._mul_scalar(self, other)
#     123 def _mul_scalar(self, other):
# --> 124     return self._with_data(self.data * other)
#
# TypeError: unsupported operand type(s) for *: 'float' and 'ellipsis'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 5
#       2 df_profile = pd.merge(df_ratings, df_features[['movieId','feature_vector']],
#       3               on='movieId')
#       4 #scaling feature vector by rating (this will take a few minutes)
# ----> 5 df_profile['feature_vector_scaled'] = df_profile['rating_scaled'] * df_profile['feature_vector']
#       6 df_profile
#
# File ~/opt/anaconda3/envs/data-in-production/lib/python3.10/site-packages/pandas/core/ops/common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~/opt/anaconda3/envs/data-in-production/lib/python3.10/site-packages/pandas/core/arraylike.py:118, in OpsMixin.__mul__(self, other)
#     116 @unpack_zerodim_and_defer("__mul__")
#     117 def __mul__(self, other):
# --> 118     return self._arith_method(other, operator.mul)
#
# File ~/opt/anaconda3/envs/data-in-production/lib/python3.10/site-packages/pandas/core/series.py:6259, in Series._arith_method(self, other, op)
#    6257 def _arith_method(self, other, op):
#    6258     self, other = ops.align_method_SERIES(self, other)
# -> 6259     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~/opt/anaconda3/envs/data-in-production/lib/python3.10/site-packages/pandas/core/base.py:1325, in IndexOpsMixin._arith_method(self, other, op)
#    1322 rvalues = ensure_wrapped_if_datetimelike(rvalues)
#    1324 with np.errstate(all="ignore"):
# -> 1325     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1327 return self._construct_result(result, name=res_name)
#
# File ~/opt/anaconda3/envs/data-in-production/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:226, in arithmetic_op(left, right, op)
#     222     _bool_arith_check(op, left, right)
#     224     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     225     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 226     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     228 return res_values
#
# File ~/opt/anaconda3/envs/data-in-production/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:172, in _na_arithmetic_op(left, right, op, is_cmp)
#     166 except TypeError:
#     167     if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#     168         # For object dtype, fallback to a masked operation (only operating
#     169         #  on the non-missing values)
#     170         # Don't do this for comparisons, as that will handle complex numbers
#     171         #  incorrectly, see GH#32047
# --> 172         result = _masked_arith_op(left, right, op)
#     173     else:
#     174         raise
#
# File ~/opt/anaconda3/envs/data-in-production/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:110, in _masked_arith_op(x, y, op)
#     108     # See GH#5284, GH#5035, GH#19448 for historical reference
#     109     if mask.any():
# --> 110         result[mask] = op(xrav[mask], yrav[mask])
#     112 else:
#     113     if not is_scalar(y):
#
# File ~/opt/anaconda3/envs/data-in-production/lib/python3.10/site-packages/scipy/sparse/_base.py:620, in spmatrix.__rmul__(self, other)
#     619 def __rmul__(self, other):  # other * self
# --> 620     return self._rmul_dispatch(other)
#
# File ~/opt/anaconda3/envs/data-in-production/lib/python3.10/site-packages/scipy/sparse/_base.py:614, in spmatrix._rmul_dispatch(self, other)
#     612 except AttributeError:
#     613     tr = np.asarray(other).transpose()
# --> 614 ret = self.transpose()._mul_dispatch(tr)
#     615 if ret is NotImplemented:
#     616     return NotImplemented
#
# File ~/opt/anaconda3/envs/data-in-production/lib/python3.10/site-packages/scipy/sparse/_base.py:536, in spmatrix._mul_dispatch(self, other)
#     532         return self._mul_multivector(other)
#     534 if isscalarlike(other):
#     535     # scalar value
# --> 536     return self._mul_scalar(other)
#     538 if issparse(other):
#     539     if self.shape[1] != other.shape[0]:
#
# File ~/opt/anaconda3/envs/data-in-production/lib/python3.10/site-packages/scipy/sparse/_data.py:124, in _data_matrix._mul_scalar(self, other)
#     123 def _mul_scalar(self, other):
# --> 124     return self._with_data(self.data * other)
#
# TypeError: unsupported operand type(s) for *: 'float' and 'ellipsis'

# %%
start = time.time()
#stack all sparse vectors of user's movies
df_user_vectors = df_profile[['userId', 'feature_vector_scaled']].groupby('userId').agg(sparse.vstack).reset_index()
#compute the average of the vectors without considering the zero entries (this will take a while)
df_user_vectors['feature_vector_scaled'] = df_user_vectors['feature_vector_scaled'].apply(lambda x: csr_matrix(np.nan_to_num(x.sum(axis=0)/x.getnnz(axis=0), 0)))
end = time.time()
print(end - start)
df_user_vectors

# %% [markdown]
# ### Step 4: Rank potential recommendation candidates

# %%
#pick a target user to provide recommendations to
idx = 42
target_userId = df_user_vectors.iloc[idx].userId

# %%
#get user rating history
df_user_history = ...

#select candidate recommendations to user
df_recommendation = ...

# %%
df_recommendation

# %%
df_user_history.head(10)

# %%
df_user_history.tail(10)

# %% [markdown]
# ### Step 5: Predict ratings of candidate items

# %%
#index all user vectors into LSH
df_usr = df_profile[df_profile['userId'] == target_userId]
lsh_usr = LSH(...)
lsh_usr.index(..., extra_data=[...]) # repeat for all users. Insert movieid and rating as extra data for future retrieval
lsh_usr

# %%
# compute recommendation
df_recommendation = ...

# %% [markdown]
# ## Collaborative filtering

# %%
from surprise import SVD
from surprise import Reader
from surprise import Dataset
from surprise.model_selection import cross_validate
from surprise.prediction_algorithms.knns import KNNBasic

# %%
directory = 'data/movielens/ml-latest-small'
#directory = 'data/movielens/ml-latest' #change into this one for the full dataset (slow)
df_ratings = pd.read_csv(f'{directory}/ratings.csv')
df_ratings.head()

# %%
# initialize a data reader
reader = Reader(rating_scale=(1, 5))
# provide a dataset with userid, itemtid, and rating in order
data = Dataset.load_from_df(df_ratings[['userId','movieId','rating']], reader)

# surprise has also some built-in datasets that can be imported directly
#data = Dataset.load_builtin('ml-100k')

# %%
# initialize a user-based K nearest neighbors implementation
anti_set = data.build_full_trainset().build_anti_testset()
anti_set

# execute 5-fold cross-validation and measure RMSE and MAE
# ...
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # initialize a user-based K nearest neighbors implementation
# ----> 2 anti_set = data.build_full_trainset().build_anti_testset()
#       3 anti_set
#       5 # execute 5-fold cross-validation and measure RMSE and MAE
#       6 # ...
#
# NameError: name 'data' is not defined
